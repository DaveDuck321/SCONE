# %%
import numpy as np
import json
from itertools import product

# %%
data = json.load(open("output.json"))

# %%
current_data = data["active"]["current"]
current_matrix = np.array(current_data["JM"])

transport_data = data["active"]["TransportXS"]
transportXS_matrix = np.array(transport_data["transportXS"])
totalXS_matrix = np.array(transport_data["totalXS"])
raw_scatterXS = np.array(transport_data["scatterXS"])
scatterXS_matrix = np.array(transport_data["scatteringProductionXS"])
fissionXS_matrix = np.array(transport_data["fissionProductionXS"])
raw_fissionXS = np.array(transport_data["fissionXS"])
nu_bar_matrix = np.array(transport_data["nuBar"])
flux_matrix = np.array(data["active"]["fluxMap"]["Res"])

# TODO: properly extract spacing
spacing = [2, 5, 2]

beta = 0

# %%
flux_matrix.shape
# Out:
# (5, 20, 5, 1, 1, 2)

# %%
current_max_x = len(current_data["XBounds"]) + 1
current_max_y = len(current_data["YBounds"]) + 1
current_max_z = len(current_data["ZBounds"]) + 1
current_max_energy_group = len(transport_data["EnergyBounds"][0])

mesh_size_x = len(current_data["XBounds"])
mesh_size_y = len(current_data["YBounds"])
mesh_size_z = len(current_data["ZBounds"])

# %%
print(current_matrix.shape)
print(flux_matrix.shape)
print(transportXS_matrix.shape)

print(scatterXS_matrix.shape)
print(fissionXS_matrix.shape)

print()

for i0, i0_l in enumerate(current_matrix):
    for i1, i1_l in enumerate(i0_l):
        for i2, i2_l in enumerate(i1_l):
            for i3, i3_l in enumerate(i2_l):
                for i4, i4_l in enumerate(i3_l):
                    for i5, i5_l in enumerate(i4_l):
                        if current_matrix[i0, i1, i2, i3, i4, i5]:
                            print(i0, i1, i2, i3, i4, i5, current_matrix[i0, i1, i2, i3, i4, i5])
# Out:
# (1, 3, 6, 21, 6, 2)
# (5, 20, 5, 1, 1, 2)
# (5, 20, 5, 1, 2)
# (5, 20, 5, 1, 1, 2)
# (5, 20, 5, 1, 1, 2)
#
# 0 0 1 1 0 0 -6.36328
# 0 0 1 1 0 1 0.257778
# 0 0 1 1 1 0 -1.34116
# 0 0 1 1 1 1 0.137056
# 0 0 1 1 2 0 0.418751
# 0 0 1 1 2 1 0.177682
# 0 0 1 1 3 0 2.6513
# 0 0 1 1 3 1 0.163117
# 0 0 1 1 4 0 4.12871
# 0 0 1 1 4 1 0.138435
# 0 0 1 1 5 0 4.44855
# 0 0 1 1 5 1 0.133769
# 0 0 1 2 0 0 -11.367
# 0 0 1 2 0 1 0.349028
# 0 0 1 2 1 0 -2.0362
# 0 0 1 2 1 1 0.184953
# 0 0 1 2 2 0 0.813687
# 0 0 1 2 2 1 0.244661
# 0 0 1 2 3 0 5.24906
# 0 0 1 2 3 1 0.224028
# 0 0 1 2 4 0 8.31034
# 0 0 1 2 4 1 0.229708
# 0 0 1 2 5 0 8.72926
# 0 0 1 2 5 1 0.231283
# 0 0 1 3 0 0 -9.9485
# 0 0 1 3 0 1 0.291587
# 0 0 1 3 1 0 -1.9987
# 0 0 1 3 1 1 0.184314
# 0 0 1 3 2 0 0.613695
# 0 0 1 3 2 1 0.198279
# 0 0 1 3 3 0 4.28061
# 0 2 5 16 5 1 0.195421
# 0 2 5 17 1 0 7.69059
# 0 2 5 17 1 1 0.149164
# 0 2 5 17 2 0 11.9946
# 0 2 5 17 2 1 0.258355
# 0 2 5 17 3 0 13.3031
# 0 2 5 17 3 1 0.232345
# 0 2 5 17 4 0 12.2897
# 0 2 5 17 4 1 0.200774
# 0 2 5 17 5 0 8.11668
# 0 2 5 17 5 1 0.159158
# 0 2 5 18 1 0 6.95289
# 0 2 5 18 1 1 0.182707
# 0 2 5 18 2 0 10.7879
# 0 2 5 18 2 1 0.223708
# 0 2 5 18 3 0 11.7636
# 0 2 5 18 3 1 0.191114
# 0 2 5 18 4 0 10.4115
# 0 2 5 18 4 1 0.18323
# 0 2 5 18 5 0 7.09664
# 0 2 5 18 5 1 0.234821
# 0 2 5 19 1 0 7.89314
# 0 2 5 19 1 1 0.185987
# 0 2 5 19 2 0 12.1489
# 0 2 5 19 2 1 0.169571
# 0 2 5 19 3 0 13.0264
# 0 2 5 19 3 1 0.214024
# 0 2 5 19 4 0 11.6636
# 0 2 5 19 4 1 0.204754
# 0 2 5 19 5 0 7.72224
# 0 2 5 19 5 1 0.186255
# 0 2 5 20 1 0 5.09988
# 0 2 5 20 1 1 0.164407
# 0 2 5 20 2 0 7.81387
# 0 2 5 20 2 1 0.243972
# 0 2 5 20 3 0 8.51851
# 0 2 5 20 3 1 0.263365
# 0 2 5 20 4 0 7.40088
# 0 2 5 20 4 1 0.191477
# 0 2 5 20 5 0 4.92779
# 0 2 5 20 5 1 0.188275

# %%
def print_matrix(matrix):
    return
    for row in matrix:
        for item in row:
            rounded = round(item, 4)
            if item == 0:
                print(f"{'--':<8}", end=" ")
            else:
                print(f"{rounded:<8}", end=" ")
        print("\n")

# %%
def get_current_on_cell_boundary_plus_half(direction, x, y, z, energy_group):
    # coord, direction, energy, mean/ std
    return current_matrix[energy_group, direction, x + 1, y + 1, z + 1, 0]

def get_flux_at_coordinate(x, y, z, energy_group):
    return flux_matrix[z, y, x, energy_group, 0, 0] / (spacing[0] * spacing[1] * spacing[2])

def get_transportXS_at_coordinate(x, y, z, energy_group):
    return transportXS_matrix[z, y, x, energy_group, 0]

def get_totalXS_at_coordinate(x, y, z, energy_group):
    return totalXS_matrix[z, y, x, energy_group, 0]

def get_scatter_xs(energy_to, energy_from, x, y, z):
    # TODO: check this
    return scatterXS_matrix[z, y, x, energy_from, energy_to, 0]

def get_raw_scatter_xs(energy, x, y, z):
    # TODO: check this
    return raw_scatterXS[z, y, x, energy, 0]

def get_raw_fission_xs(energy, x, y, z):
    # TODO: check this
    return raw_fissionXS[z, y, x, energy, 0]

def get_nu_bar(energy, x, y, z):
    # TODO: check this
    return nu_bar_matrix[z, y, x, energy, 0]

def get_fission_xs(energy_to, energy_from, x, y, z):
    # TODO: check this
    return fissionXS_matrix[z, y, x, energy_from, energy_to, 0]

# %%
print(get_raw_scatter_xs(0, 0, 5, 0))
print(get_scatter_xs(0, 0, 0, 5, 0))

print()

print(get_raw_fission_xs(0, 0, 5, 0))
print(get_fission_xs(0, 0, 0, 5, 0))
print(get_nu_bar(0, 0, 5, 0))

print()

print(get_transportXS_at_coordinate(0, 5, 0, 0))
print(get_totalXS_at_coordinate(0, 5, 0, 0))
# Out:
# 3.32483
# 3.3254
#
# 0.162386
# 0.162386
# 2.47622
#
# 1.4465
# 3.54165

# %%
# Calculate k_inf
# Do I need to remove scattering multiplicity here?
absorption_xs = get_totalXS_at_coordinate(0, 5, 0, 0) - get_scatter_xs(0, 0, 0, 5, 0)
print(absorption_xs)

# Assume utilization factor = 1

eta = get_nu_bar(0, 0, 5, 0) * get_fission_xs(0, 0, 0, 5, 0) / absorption_xs
k_inf = eta * absorption_xs
print(eta)
# Out:
# 0.21625000000000005
# 1.859437969572254

# %%
diffusion_coefficient = np.zeros((mesh_size_x, mesh_size_y, mesh_size_z, current_max_energy_group))

for x, y, z, energy in product(range(mesh_size_x), range(mesh_size_y), range(mesh_size_z), range(current_max_energy_group)):
    transport_XS = get_transportXS_at_coordinate(x, y, z, energy)
    assert transport_XS > 0
    diffusion_coefficient[x, y, z, energy] = 1.0 / (3.0 * transport_XS)

# %%
def build_linear_diffusive_term(direction):
    linear_diffusive_term_positive = np.zeros((mesh_size_x, mesh_size_y, mesh_size_z, current_max_energy_group))
    linear_diffusive_term_negative = np.zeros((mesh_size_x, mesh_size_y, mesh_size_z, current_max_energy_group))

    for x, y, z, energy in product(range(mesh_size_x), range(mesh_size_y), range(mesh_size_z), range(current_max_energy_group)):
        D = diffusion_coefficient[x, y, z, energy]

        is_on_high_boundary = [x == mesh_size_x - 1, y == mesh_size_y - 1, z == mesh_size_z - 1][direction]
        is_on_low_boundary = [x == 0, y == 0, z == 0][direction]
        delta_x, delta_y, delta_z = [(1, 0, 0), (0, 1, 0), (0, 0, 1)][direction]

        if is_on_low_boundary:
            coupling = (2 * D * (1 - beta)) / (4 * D * (1 + beta) + (1 - beta) * spacing[direction])
        else:
            D_minus_1 = diffusion_coefficient[x - delta_x, y - delta_y, z - delta_z, energy]
            coupling = (2 * D_minus_1 * D) / ((D_minus_1 + D) * spacing[direction])

        linear_diffusive_term_negative[x, y, z, energy] = coupling

        if is_on_high_boundary:
            coupling = (2 * D * (1 - beta)) / (4 * D * (1 + beta) + (1 - beta) * spacing[direction])
        else:
            D_plus_1 = diffusion_coefficient[x + delta_x, y + delta_y, z + delta_z, energy]
            coupling = (2 * D_plus_1 * D) / ((D_plus_1 + D) * spacing[direction])
        
        linear_diffusive_term_positive[x, y, z, energy] = coupling
    return linear_diffusive_term_negative, linear_diffusive_term_positive

# %%
POSITIVE_DIR = 1
NEGATIVE_DIR = 0
linear_diffusive_terms = [build_linear_diffusive_term(0), build_linear_diffusive_term(1), build_linear_diffusive_term(2)]

print(linear_diffusive_terms[1][POSITIVE_DIR].T)

print(linear_diffusive_terms[1][NEGATIVE_DIR].T)
# Out:
# [[[[0.0454746  0.04430665 0.04426429 0.04444281 0.04635166]
#    [0.04548204 0.04448626 0.04369779 0.04431784 0.04589061]
#   [[0.07790543 0.07504733 0.07356417 0.0764659  0.07784267]
#    [0.04613403 0.0440403  0.04324455 0.04463713 0.04599287]
#    [0.04587387 0.04412965 0.04378749 0.04420647 0.04591953]
#    [0.04542363 0.0441526  0.04425254 0.04434482 0.04611966]
#    [0.0457833  0.04428428 0.04423022 0.04418244 0.04604099]
#    [0.04572176 0.04434349 0.04421409 0.04414485 0.0458365 ]
#    [0.04536011 0.04394233 0.04419841 0.04413418 0.0454388 ]
#    [0.04574482 0.04390789 0.0441225  0.04398843 0.04548406]
#    [0.04583004 0.04430488 0.04403899 0.04420031 0.04548949]
#    [0.04571361 0.04439236 0.04426444 0.0444209  0.04554761]
#    [0.0458775  0.04436577 0.04435013 0.04429797 0.04577183]
#    [0.04560556 0.04440078 0.04428325 0.04456671 0.04556208]
#    [0.04522932 0.04430739 0.04431313 0.04452786 0.04586299]
#    [0.04546235 0.04453797 0.04424475 0.04445912 0.04582264]
#    [0.04568604 0.04489504 0.04425224 0.04480678 0.04558405]
#    [0.04566007 0.04462189 0.04441883 0.04455762 0.04599271]
#    [0.04579777 0.04436651 0.04448344 0.04433936 0.04602129]
#    [0.04604226 0.04457252 0.04446282 0.04425004 0.04561773]
#    [0.04638133 0.04463623 0.0443283  0.04421526 0.04561461]
#    [0.04634409 0.04438113 0.04422054 0.04408967 0.04531695]]]]

# %%
def build_non_linear_diffusive_term(direction):
    non_linear_diffusive_term_positive = np.zeros((mesh_size_x, mesh_size_y, mesh_size_z, current_max_energy_group))
    non_linear_diffusive_term_negative = np.zeros((mesh_size_x, mesh_size_y, mesh_size_z, current_max_energy_group))

    for x, y, z, energy in product(range(mesh_size_x), range(mesh_size_y), range(mesh_size_z), range(current_max_energy_group)):
        flux = get_flux_at_coordinate(x, y, z, energy)

        is_on_high_boundary = [x == mesh_size_x - 1, y == mesh_size_y - 1, z == mesh_size_z - 1][direction]
        is_on_low_boundary = [x == 0, y == 0, z == 0][direction]
        delta_x, delta_y, delta_z = [(1, 0, 0), (0, 1, 0), (0, 0, 1)][direction]

        J_minus_half_tallied = get_current_on_cell_boundary_plus_half(direction, x - delta_x, y - delta_y, z - delta_z, energy)
        D_linear = linear_diffusive_terms[direction][NEGATIVE_DIR][x, y, z, energy]

        if is_on_low_boundary:
            non_linear_term = (J_minus_half_tallied + D_linear * flux) / flux
        else:
            flux_minus_1 = get_flux_at_coordinate(x - delta_x, y - delta_y, z - delta_z, energy)

            print(f"Current-: {J_minus_half_tallied}, Linear estimate: {-D_linear * (-flux_minus_1 + flux)}")
            non_linear_term = (J_minus_half_tallied + D_linear * (-flux_minus_1 + flux)) / (flux_minus_1 + flux)

        non_linear_diffusive_term_negative[x, y, z, energy] = non_linear_term

        J_plus_half_tallied = get_current_on_cell_boundary_plus_half(direction, x, y, z, energy)
        D_linear = linear_diffusive_terms[direction][POSITIVE_DIR][x, y, z, energy]
        if is_on_high_boundary:
            non_linear_term = (J_plus_half_tallied - D_linear * flux) / flux
        else:
            flux_plus_1 = get_flux_at_coordinate(x + delta_x, y + delta_y, z + delta_z, energy)

            print(f"Current+: {J_plus_half_tallied}, Linear estimate: {-D_linear * (flux_plus_1 - flux)}")
            non_linear_term = (J_plus_half_tallied + D_linear * (flux_plus_1 - flux)) / (flux_plus_1 + flux)
        
        non_linear_diffusive_term_positive[x, y, z, energy] = non_linear_term


        non_linear_diffusive_term_negative[x, y, z, energy] = 0
        non_linear_diffusive_term_positive[x, y, z, energy] = 0

    return non_linear_diffusive_term_negative, non_linear_diffusive_term_positive

# %%
non_linear_diffusive_terms = [build_non_linear_diffusive_term(0), build_non_linear_diffusive_term(1), build_non_linear_diffusive_term(2)]
# Out:
# Current+: -1.34116, Linear estimate: -0.5033087647911226
# Current+: 0.418751, Linear estimate: -0.7505106205784212
# Current+: 2.6513, Linear estimate: -0.87734070671052
# Current+: 4.12871, Linear estimate: -0.7120250739497606
# Current+: 4.44855, Linear estimate: -0.5297369252290058
# Current+: -2.0362, Linear estimate: -0.926423654779775
# Current+: 0.813687, Linear estimate: -1.4263596383402983
# Current+: 5.24906, Linear estimate: -1.6060002620485483
# Current+: 8.31034, Linear estimate: -1.425069544459131
# Current+: 8.72926, Linear estimate: -0.9234883412198576
# Current+: -1.9987, Linear estimate: -0.7897993622497639
# Current+: 0.613695, Linear estimate: -1.1815212931812593
# Current+: 4.28061, Linear estimate: -1.337066237317524
# Current+: 7.00995, Linear estimate: -1.1627930075486685
# Current+: 7.12651, Linear estimate: -0.7750658221643633
# Current+: -1.99105, Linear estimate: -0.8839810467156513
# Current+: 0.563075, Linear estimate: -1.1622978133423871
# Current+: 4.96393, Linear estimate: -1.4979569759333717
# Current+: 7.80835, Linear estimate: -1.2944605745220514
# Current+: 7.90419, Linear estimate: -0.8502056787398415
# Current+: -2.72132, Linear estimate: -0.9928203256648013
# Current+: 0.895025, Linear estimate: -1.4825992129085612
# Current+: 4.98425, Linear estimate: -1.6858473224176378
# Current+: 8.39932, Linear estimate: -1.4211725709550447
# Current+: 9.18348, Linear estimate: -0.9460215068427761
# Current+: -1.96481, Linear estimate: -0.796473566882194
# Current+: 0.704061, Linear estimate: -1.1875705992282064
# Current+: 4.69184, Linear estimate: -1.3376992157923497
# Current+: 6.74329, Linear estimate: -1.20116021622708
# Current+: 7.29273, Linear estimate: -0.8323522853957637
# Current+: -2.28673, Linear estimate: -0.7800647509771357
# Current+: 0.479487, Linear estimate: -1.1725876363795773
# Current+: 3.84714, Linear estimate: -1.3314216669338421
# Current+: 6.75131, Linear estimate: -1.1847442984919705
# Current+: 7.35003, Linear estimate: -0.810716152990227
# Current+: -2.20634, Linear estimate: -0.7542793874573527
# Current+: 0.798672, Linear estimate: -1.1546373091100577
# Current+: 4.52511, Linear estimate: -1.354150587921044
# Current+: 7.15976, Linear estimate: -1.1664269774361522
# Current+: 7.23265, Linear estimate: -0.8265490880581561
# Current+: -2.13345, Linear estimate: -0.9103729044267611
# Current+: 0.62805, Linear estimate: -1.3037863713510405
# Current+: 4.64524, Linear estimate: -1.441279415780753
# Current+: 7.66216, Linear estimate: -1.2643040201882607
# %%
print(flux_matrix[0, :, 0, 0, 0, 0])
# Out:
# [173.125 334.049 289.834 310.893 352.143 291.465 280.064 298.96  311.433
#  326.013 337.879 331.615 287.189 324.528 320.952 362.368 316.806 284.618
#  303.15  196.886]

# %%
# Generate neutron loss matrix

delta_test = 0
number_of_groups = mesh_size_x * mesh_size_y * mesh_size_z * current_max_energy_group
neutron_loss_matrix = np.zeros((number_of_groups, number_of_groups))

def get_index_in_flattened_flux_vector(energy, x, y, z):
    return energy * (mesh_size_x * mesh_size_y * mesh_size_z) + z * (mesh_size_y * mesh_size_x) + y * mesh_size_x + x

for x, y, z, energy in product(range(mesh_size_x), range(mesh_size_y), range(mesh_size_z), range(current_max_energy_group)):
    index_in_flattened_flux_vector = get_index_in_flattened_flux_vector(energy, x, y, z)

    for direction in range(3):
        spacing_inv = (1 / spacing[direction])

        is_on_high_boundary = [x == mesh_size_x - 1, y == mesh_size_y - 1, z == mesh_size_z - 1][direction]
        is_on_low_boundary = [x == 0, y == 0, z == 0][direction]
        delta_x, delta_y, delta_z = [(1, 0, 0), (0, 1, 0), (0, 0, 1)][direction]    

        # From flux l-1
        D_linear_minus = linear_diffusive_terms[direction][NEGATIVE_DIR][x, y, z, energy]
        D_linear_plus = linear_diffusive_terms[direction][POSITIVE_DIR][x, y, z, energy]

        D_non_linear_minus = non_linear_diffusive_terms[direction][NEGATIVE_DIR][x, y, z, energy]
        D_non_linear_plus = non_linear_diffusive_terms[direction][POSITIVE_DIR][x, y, z, energy]

        print("group")
        if not is_on_low_boundary:
            neutron_loss_matrix[index_in_flattened_flux_vector, get_index_in_flattened_flux_vector(energy, x - delta_x, y - delta_y, z - delta_z)] \
                += spacing_inv * (-D_linear_minus - D_non_linear_minus) \
                    + delta_test
            print(f"{D_linear_minus=}")

        # From flux l
        neutron_loss_matrix[index_in_flattened_flux_vector, index_in_flattened_flux_vector] \
            += spacing_inv * (D_linear_minus + D_linear_plus - D_non_linear_minus + D_non_linear_plus) \
                + delta_test
        print(f"{(D_linear_minus + D_linear_plus)=}")

        # From flux l+1
        if not is_on_high_boundary:
            neutron_loss_matrix[index_in_flattened_flux_vector, get_index_in_flattened_flux_vector(energy, x + delta_x, y + delta_y, z + delta_z)] \
                += spacing_inv * (-D_linear_plus + D_non_linear_plus) \
                    + delta_test
            print(f"{(D_linear_plus)=}")

    # Total XS
    neutron_loss_matrix[index_in_flattened_flux_vector, index_in_flattened_flux_vector] \
        += get_totalXS_at_coordinate(x, y, z, energy) \
            + delta_test

    # Scattering
    for h_energy in range(current_max_energy_group):
        neutron_loss_matrix[index_in_flattened_flux_vector, get_index_in_flattened_flux_vector(h_energy, x, y, z)] \
            -= get_scatter_xs(energy, h_energy, x, y, z) \
                - delta_test
# Out:
# group
# (D_linear_minus + D_linear_plus)=0.2673585527895986
# (D_linear_plus)=0.11172597640123925
# group
# (D_linear_minus + D_linear_plus)=0.12202390581218697
# (D_linear_plus)=0.04547459561715848
# group
# (D_linear_minus + D_linear_plus)=0.2678837856145107
# (D_linear_plus)=0.1122512092261514
# group
# (D_linear_minus + D_linear_plus)=0.26411476431793884
# (D_linear_plus)=0.10986994694380262
# group
# (D_linear_minus + D_linear_plus)=0.12007760665667666
# (D_linear_plus)=0.044365916771758426
# group
# D_linear_minus=0.1122512092261514
# (D_linear_minus + D_linear_plus)=0.2232871859929836
# (D_linear_plus)=0.11103597676683222
# group
# (D_linear_minus + D_linear_plus)=0.2631599328486649
# (D_linear_plus)=0.109853652963522
# group
# (D_linear_minus + D_linear_plus)=0.11921437647272276
# (D_linear_plus)=0.04406722896450826
# group
# D_linear_minus=0.11103597676683222
# (D_linear_minus + D_linear_plus)=0.22138677090632225
# (D_linear_plus)=0.11035079413949003
# group
# (D_linear_minus + D_linear_plus)=0.26239988422403815
# (D_linear_plus)=0.10947410827865103
# group
# (D_linear_minus + D_linear_plus)=0.11922492226832151
# (D_linear_plus)=0.04430620907213936
# group
# D_linear_minus=0.11035079413949003
# (D_linear_minus + D_linear_plus)=0.22304526253150903
# (D_linear_plus)=0.11269446839201899
# group
# (D_linear_minus + D_linear_plus)=0.2706781945920703
# (D_linear_plus)=0.11281079373674475
# group
# (D_linear_minus + D_linear_plus)=0.1240394607547542
# (D_linear_plus)=0.046134026266407856
# group
# D_linear_minus=0.11269446839201899
# (D_linear_minus + D_linear_plus)=0.2705618692473446
# group
# (D_linear_minus + D_linear_plus)=0.2696612082012232
# (D_linear_plus)=0.11269332539972322
# group
# D_linear_minus=0.04547459561715848
# (D_linear_minus + D_linear_plus)=0.09095663703310539
# (D_linear_plus)=0.04548204141594691
# group
# (D_linear_minus + D_linear_plus)=0.26928376898507356
# (D_linear_plus)=0.11231588618357356
# group
# (D_linear_minus + D_linear_plus)=0.2623381101278365
# (D_linear_plus)=0.10926274959709362
# group
# D_linear_minus=0.044365916771758426
# (D_linear_minus + D_linear_plus)=0.08856095389006523
# (D_linear_plus)=0.0441950371183068
# group
# D_linear_minus=0.11231588618357356
# (D_linear_minus + D_linear_plus)=0.2223646598000404
# (D_linear_plus)=0.11004877361646681
# group
# (D_linear_minus + D_linear_plus)=0.26085961009830716
# (D_linear_plus)=0.10828452408410244
# group
# D_linear_minus=0.04406722896450826
# (D_linear_minus + D_linear_plus)=0.0878360290319122
# (D_linear_plus)=0.04376880006740395
# group
# D_linear_minus=0.11004877361646681
# (D_linear_minus + D_linear_plus)=0.22063019969665382
# (D_linear_plus)=0.11058142608018702
# group
# (D_linear_minus + D_linear_plus)=0.2637130367225137
# (D_linear_plus)=0.10960513653511857
# group
# D_linear_minus=0.04430620907213936
# (D_linear_minus + D_linear_plus)=0.08904773726377628
# (D_linear_plus)=0.04474152819163692
# group
# D_linear_minus=0.11058142608018702
# (D_linear_minus + D_linear_plus)=0.2238969008946896
# (D_linear_plus)=0.11331547481450258
# group
# (D_linear_minus + D_linear_plus)=0.2703331887361031
# (D_linear_plus)=0.11250390951085551
# group
# D_linear_minus=0.046134026266407856
# (D_linear_minus + D_linear_plus)=0.0920079006362155
# (D_linear_plus)=0.04587387436980765
# group
# D_linear_minus=0.11331547481450258
# (D_linear_minus + D_linear_plus)=0.27114475403975025
# group
# (D_linear_minus + D_linear_plus)=0.2678684195661389
# (D_linear_plus)=0.11220095640095235
# group
# D_linear_minus=0.04548204141594691
# (D_linear_minus + D_linear_plus)=0.09087535747712348
# (D_linear_plus)=0.045393316061176574
# group
# (D_linear_minus + D_linear_plus)=0.2674991430671325
# (D_linear_plus)=0.111831679901946
# group
# (D_linear_minus + D_linear_plus)=0.26282608046421463
# (D_linear_plus)=0.10940619786110882
# group
# D_linear_minus=0.0441950371183068
# (D_linear_minus + D_linear_plus)=0.08817084602582678
# (D_linear_plus)=0.043975808907519974
# group
# D_linear_minus=0.111831679901946
# (D_linear_minus + D_linear_plus)=0.22168750511693386
# (D_linear_plus)=0.10985582521498785
# group
# (D_linear_minus + D_linear_plus)=0.2605063396655942
# (D_linear_plus)=0.10864097742114567
# group
# D_linear_minus=0.04376880006740395
# (D_linear_minus + D_linear_plus)=0.0875167767234836
# (D_linear_plus)=0.04374797665607965
# group
# D_linear_minus=0.10985582521498785
# (D_linear_minus + D_linear_plus)=0.2205235277313501
# (D_linear_plus)=0.11066770251636222
# group
# (D_linear_minus + D_linear_plus)=0.26536865704512885
# (D_linear_plus)=0.11036065863241074
# group
# D_linear_minus=0.04474152819163692
# (D_linear_minus + D_linear_plus)=0.08931613047474804
# (D_linear_plus)=0.04457460228311113
# group
# D_linear_minus=0.11066770251636222
# (D_linear_minus + D_linear_plus)=0.22385543115557408
# (D_linear_plus)=0.11318772863921185
# group
# (D_linear_minus + D_linear_plus)=0.26907185369938535
# (D_linear_plus)=0.11242043443752683
# group
# D_linear_minus=0.04587387436980765
# (D_linear_minus + D_linear_plus)=0.09129750078773453
# (D_linear_plus)=0.04542362641792688
# group
# D_linear_minus=0.11318772863921185
# (D_linear_minus + D_linear_plus)=0.26983914790107033
# group
# (D_linear_minus + D_linear_plus)=0.26930895144471345
# (D_linear_plus)=0.11276347185198216
# group
# D_linear_minus=0.045393316061176574
# (D_linear_minus + D_linear_plus)=0.09084202548826151
# (D_linear_plus)=0.045448709427084934
# group
# (D_linear_minus + D_linear_plus)=0.2680807966932146
# (D_linear_plus)=0.1115353171004833
# group
# (D_linear_minus + D_linear_plus)=0.26085219365678625
# (D_linear_plus)=0.10882683582710029
# group
# D_linear_minus=0.043975808907519974
# (D_linear_minus + D_linear_plus)=0.0880322628475988
# (D_linear_plus)=0.04405645394007882
# group
# D_linear_minus=0.1115353171004833
# (D_linear_minus + D_linear_plus)=0.2209882167814281
# (D_linear_plus)=0.10945289968094479
# group
# (D_linear_minus + D_linear_plus)=0.2610876084971464
# (D_linear_plus)=0.10861371965061138
# group
# D_linear_minus=0.04374797665607965
# (D_linear_minus + D_linear_plus)=0.0879808405681447
# (D_linear_plus)=0.04423286391206506
# group
# D_linear_minus=0.10945289968094479
# (D_linear_minus + D_linear_plus)=0.2195736581046322
# (D_linear_plus)=0.11012075842368742
# group
# (D_linear_minus + D_linear_plus)=0.26254988807654944
# (D_linear_plus)=0.10923303119476904
# group
# D_linear_minus=0.04457460228311113
# (D_linear_minus + D_linear_plus)=0.08901489896653178
# (D_linear_plus)=0.04444029668342066
# group
# D_linear_minus=0.11012075842368742
# (D_linear_minus + D_linear_plus)=0.22191718160892404
# (D_linear_plus)=0.11179642318523661
# group
# (D_linear_minus + D_linear_plus)=0.26718426661159367
# (D_linear_plus)=0.11147899178399831
# group
# D_linear_minus=0.04542362641792688
# (D_linear_minus + D_linear_plus)=0.09120692718788755
# (D_linear_plus)=0.045783300769960664
# group
# D_linear_minus=0.11179642318523661
# (D_linear_minus + D_linear_plus)=0.26750169801283197
# group
# (D_linear_minus + D_linear_plus)=0.2685681660778497
# (D_linear_plus)=0.11264001153433717
# group
# D_linear_minus=0.045448709427084934
# (D_linear_minus + D_linear_plus)=0.09114884115771466
# (D_linear_plus)=0.045700131730629714
# group
# (D_linear_minus + D_linear_plus)=0.2681034351499769
# (D_linear_plus)=0.11217528060646442
# group
# (D_linear_minus + D_linear_plus)=0.26291889289850334
# (D_linear_plus)=0.10910610459565824
# group
# D_linear_minus=0.04405645394007882
# (D_linear_minus + D_linear_plus)=0.08851260517101409
# (D_linear_plus)=0.044456151230935256
# group
# D_linear_minus=0.11217528060646442
# (D_linear_minus + D_linear_plus)=0.22345999587339194
# (D_linear_plus)=0.1112847152669275
# group
# (D_linear_minus + D_linear_plus)=0.26356650120038205
# (D_linear_plus)=0.1093537956155689
# group
# D_linear_minus=0.04423286391206506
# (D_linear_minus + D_linear_plus)=0.08841369605803852
# (D_linear_plus)=0.04418083214597346
# group
# D_linear_minus=0.1112847152669275
# (D_linear_minus + D_linear_plus)=0.222855124562974
# (D_linear_plus)=0.11157040929604649
# group
# (D_linear_minus + D_linear_plus)=0.2639718064405073
# (D_linear_plus)=0.10961270542791157
# group
# D_linear_minus=0.04444029668342066
# (D_linear_minus + D_linear_plus)=0.08890371218514584
# (D_linear_plus)=0.04446341550172518
# group
# D_linear_minus=0.11157040929604649
# (D_linear_minus + D_linear_plus)=0.22529956558492764
# (D_linear_plus)=0.11372915628888117
# group
# (D_linear_minus + D_linear_plus)=0.2720161760865615
# (D_linear_plus)=0.11364850336285921
# group
# D_linear_minus=0.045783300769960664
# (D_linear_minus + D_linear_plus)=0.09150505872583231
# (D_linear_plus)=0.04572175795587164
# group
# D_linear_minus=0.11372915628888117
# (D_linear_minus + D_linear_plus)=0.2720968290125834
# group
# (D_linear_minus + D_linear_plus)=0.26981949402599725
# (D_linear_plus)=0.11207834724786016
# group
# D_linear_minus=0.045700131730629714
# (D_linear_minus + D_linear_plus)=0.09149711370951732
# (D_linear_plus)=0.0457969819788876
# group
# (D_linear_minus + D_linear_plus)=0.2709181148124342
# (D_linear_plus)=0.11317696803429715
# group
# (D_linear_minus + D_linear_plus)=0.2632858816182876
# (D_linear_plus)=0.10935020825747163
# group
# D_linear_minus=0.044456151230935256
# (D_linear_minus + D_linear_plus)=0.08878357128643319
# (D_linear_plus)=0.044327420055497925
# group
# D_linear_minus=0.11317696803429715
# (D_linear_minus + D_linear_plus)=0.2234868616183428
# (D_linear_plus)=0.11030989358404565
# group
# (D_linear_minus + D_linear_plus)=0.26085775991745364
# (D_linear_plus)=0.10863106392177692
# group
# D_linear_minus=0.04418083214597346
# (D_linear_minus + D_linear_plus)=0.08795538009168864
# (D_linear_plus)=0.043774547945715184
# group
# D_linear_minus=0.11030989358404565
# (D_linear_minus + D_linear_plus)=0.22035830387973473
# (D_linear_plus)=0.11004841029568908
# group
# (D_linear_minus + D_linear_plus)=0.26265460635012544
# (D_linear_plus)=0.1092276621238882
# group
# D_linear_minus=0.04446341550172518
# (D_linear_minus + D_linear_plus)=0.08887825005646646
# (D_linear_plus)=0.04441483455474128
# group
# D_linear_minus=0.11004841029568908
# (D_linear_minus + D_linear_plus)=0.221756414509315
# (D_linear_plus)=0.11170800421362591
# group
# (D_linear_minus + D_linear_plus)=0.2669034051173309
# (D_linear_plus)=0.11148272017837235
# group
# D_linear_minus=0.04572175795587164
# (D_linear_minus + D_linear_plus)=0.09108187190047787
# (D_linear_plus)=0.04536011394460623
# group
# D_linear_minus=0.11170800421362591
# (D_linear_minus + D_linear_plus)=0.2671286891525844
# group
# (D_linear_minus + D_linear_plus)=0.26821193206136607
# (D_linear_plus)=0.11183243028645876
# group
# D_linear_minus=0.0457969819788876
# (D_linear_minus + D_linear_plus)=0.09138601508108454
# (D_linear_plus)=0.04558903310219693
# group
# (D_linear_minus + D_linear_plus)=0.2684589795742044
# (D_linear_plus)=0.11207947779929704
# group
# (D_linear_minus + D_linear_plus)=0.2627939176411035
# (D_linear_plus)=0.10959684799465166
# group
# D_linear_minus=0.044327420055497925
# (D_linear_minus + D_linear_plus)=0.08873278777634802
# (D_linear_plus)=0.04440536772085009
# group
# D_linear_minus=0.11207947779929704
# (D_linear_minus + D_linear_plus)=0.22201646191999905
# (D_linear_plus)=0.109936984120702
# group
# (D_linear_minus + D_linear_plus)=0.2612910409008419
# (D_linear_plus)=0.10905113516779154
# group
# D_linear_minus=0.043774547945715184
# (D_linear_minus + D_linear_plus)=0.08775267762182726
# (D_linear_plus)=0.043978129676112074
# group
# D_linear_minus=0.109936984120702
# (D_linear_minus + D_linear_plus)=0.22035101465238974
# (D_linear_plus)=0.11041403053168773
# group
# (D_linear_minus + D_linear_plus)=0.26361672998862445
# (D_linear_plus)=0.10949172844737445
# group
# D_linear_minus=0.04441483455474128
# (D_linear_minus + D_linear_plus)=0.08911061828972211
# (D_linear_plus)=0.04469578373498082
# group
# D_linear_minus=0.11041403053168773
# (D_linear_minus + D_linear_plus)=0.22312297883322024
# (D_linear_plus)=0.1127089483015325
# group
# (D_linear_minus + D_linear_plus)=0.2683547969068925
# (D_linear_plus)=0.11171736400645281
# group
# D_linear_minus=0.04536011394460623
# (D_linear_minus + D_linear_plus)=0.0911049310568274
# (D_linear_plus)=0.045744817112221184
# group
# D_linear_minus=0.1127089483015325
# (D_linear_minus + D_linear_plus)=0.2693463812019722
# group
# (D_linear_minus + D_linear_plus)=0.26950500598357385
# (D_linear_plus)=0.11274897793051505
# group
# D_linear_minus=0.04558903310219693
# (D_linear_minus + D_linear_plus)=0.09145911984253097
# (D_linear_plus)=0.04587008674033403
# group
# (D_linear_minus + D_linear_plus)=0.2696264122186983
# (D_linear_plus)=0.11287038416563953
# group
# (D_linear_minus + D_linear_plus)=0.26401880175879944
# (D_linear_plus)=0.10970686326136564
# group
# D_linear_minus=0.04440536772085009
# (D_linear_minus + D_linear_plus)=0.08911224151446304
# (D_linear_plus)=0.044706873793612954
# group
# D_linear_minus=0.11287038416563953
# (D_linear_minus + D_linear_plus)=0.22389230766487295
# (D_linear_plus)=0.1110219234992334
# group
# (D_linear_minus + D_linear_plus)=0.26268557582561447
# (D_linear_plus)=0.10947231062111305
# group
# D_linear_minus=0.043978129676112074
# (D_linear_minus + D_linear_plus)=0.08797889968958732
# (D_linear_plus)=0.04400077001347524
# group
# D_linear_minus=0.1110219234992334
# (D_linear_minus + D_linear_plus)=0.222281380553083
# (D_linear_plus)=0.11125945705384958
# group
# (D_linear_minus + D_linear_plus)=0.26497315452394676
# (D_linear_plus)=0.1102019450643304
# group
# D_linear_minus=0.04469578373498082
# (D_linear_minus + D_linear_plus)=0.08919110115901341
# (D_linear_plus)=0.04449531742403259
# group
# D_linear_minus=0.11125945705384958
# (D_linear_minus + D_linear_plus)=0.22462348936713336
# (D_linear_plus)=0.11336403231328378
# group
# (D_linear_minus + D_linear_plus)=0.2695548932661498
# (D_linear_plus)=0.11232194164201201
# group
# D_linear_minus=0.045744817112221184
# (D_linear_minus + D_linear_plus)=0.09157485641147989
# (D_linear_plus)=0.0458300392992587
# group
# D_linear_minus=0.11336403231328378
# (D_linear_minus + D_linear_plus)=0.27059698393742154
# group
# (D_linear_minus + D_linear_plus)=0.27038569755441544
# (D_linear_plus)=0.11268037310725143
# group
# D_linear_minus=0.04587008674033403
# (D_linear_minus + D_linear_plus)=0.09164050005860891
# (D_linear_plus)=0.045770413318274875
# group
# (D_linear_minus + D_linear_plus)=0.2712419564738042
# (D_linear_plus)=0.11353663202664023
# group
# (D_linear_minus + D_linear_plus)=0.2646316172032315
# (D_linear_plus)=0.109995391193109
# group
# D_linear_minus=0.044706873793612954
# (D_linear_minus + D_linear_plus)=0.08938124232141381
# (D_linear_plus)=0.04467436852780086
# group
# D_linear_minus=0.11353663202664023
# (D_linear_minus + D_linear_plus)=0.22427014186918826
# (D_linear_plus)=0.11073350984254801
# group
# (D_linear_minus + D_linear_plus)=0.2611497117317917
# (D_linear_plus)=0.10880126035379994
# group
# D_linear_minus=0.04400077001347524
# (D_linear_minus + D_linear_plus)=0.08781415565999104
# (D_linear_plus)=0.043813385646515796
# group
# D_linear_minus=0.11073350984254801
# (D_linear_minus + D_linear_plus)=0.22071474704348154
# (D_linear_plus)=0.10998123720093354
# group
# (D_linear_minus + D_linear_plus)=0.2623224684100329
# (D_linear_plus)=0.10914933375246677
# group
# D_linear_minus=0.04449531742403259
# (D_linear_minus + D_linear_plus)=0.0883878859732515
# (D_linear_plus)=0.04389256854921892
# group
# D_linear_minus=0.10998123720093354
# (D_linear_minus + D_linear_plus)=0.22238537052572416
# (D_linear_plus)=0.11240413332479063
# group
# (D_linear_minus + D_linear_plus)=0.2699900105633235
# (D_linear_plus)=0.11295261524837714
# group
# D_linear_minus=0.0458300392992587
# (D_linear_minus + D_linear_plus)=0.09154364583996152
# (D_linear_plus)=0.04571360654070282
# group
# D_linear_minus=0.11240413332479063
# (D_linear_minus + D_linear_plus)=0.26944152863973697
# group
# (D_linear_minus + D_linear_plus)=0.26850646965464614
# (D_linear_plus)=0.11221568752868513
# group
# D_linear_minus=0.045770413318274875
# (D_linear_minus + D_linear_plus)=0.09101953803051874
# (D_linear_plus)=0.045249124712243856
# group
# (D_linear_minus + D_linear_plus)=0.2688372356746632
# (D_linear_plus)=0.11254645354870223
# group
# (D_linear_minus + D_linear_plus)=0.2638588853558623
# (D_linear_plus)=0.10970180854401566
# group
# D_linear_minus=0.04467436852780086
# (D_linear_minus + D_linear_plus)=0.08902331490770723
# (D_linear_plus)=0.044348946379906384
# group
# D_linear_minus=0.11254645354870223
# (D_linear_minus + D_linear_plus)=0.2230117111205433
# (D_linear_plus)=0.11046525757184107
# group
# (D_linear_minus + D_linear_plus)=0.2602528185333448
# (D_linear_plus)=0.10794682970955824
# group
# D_linear_minus=0.043813385646515796
# (D_linear_minus + D_linear_plus)=0.08772995295194894
# (D_linear_plus)=0.043916567305433134
# group
# D_linear_minus=0.11046525757184107
# (D_linear_minus + D_linear_plus)=0.21975093360756875
# (D_linear_plus)=0.10928567603572767
# group
# (D_linear_minus + D_linear_plus)=0.2599423375054008
# (D_linear_plus)=0.10807282379158373
# group
# D_linear_minus=0.04389256854921892
# (D_linear_minus + D_linear_plus)=0.08795906930551024
# (D_linear_plus)=0.04406650075629132
# group
# D_linear_minus=0.10928567603572767
# (D_linear_minus + D_linear_plus)=0.22080793253245673
# (D_linear_plus)=0.11152225649672906
# group
# (D_linear_minus + D_linear_plus)=0.26895124487829186
# (D_linear_plus)=0.1122659535533297
# group
# D_linear_minus=0.04571360654070282
# (D_linear_minus + D_linear_plus)=0.09159111130909597
# (D_linear_plus)=0.04587750476839315
# group
# D_linear_minus=0.11152225649672906
# (D_linear_minus + D_linear_plus)=0.2682075478216912
# group
# (D_linear_minus + D_linear_plus)=0.26641456170931965
# (D_linear_plus)=0.111174109773316
# group
# D_linear_minus=0.045249124712243856
# (D_linear_minus + D_linear_plus)=0.09063610545681727
# (D_linear_plus)=0.04538698074457341
# group
# (D_linear_minus + D_linear_plus)=0.26667211479727904
# (D_linear_plus)=0.11143166286127539
# group
# (D_linear_minus + D_linear_plus)=0.26247138455046126
# (D_linear_plus)=0.10939040011726654
# group
# D_linear_minus=0.044348946379906384
# (D_linear_minus + D_linear_plus)=0.08837921278503327
# (D_linear_plus)=0.04403026640512689
# group
# D_linear_minus=0.11143166286127539
# (D_linear_minus + D_linear_plus)=0.22162522887934272
# (D_linear_plus)=0.11019356601806732
# group
# (D_linear_minus + D_linear_plus)=0.2619901253019895
# (D_linear_plus)=0.10914218607433018
# group
# D_linear_minus=0.043916567305433134
# (D_linear_minus + D_linear_plus)=0.08808071661558911
# (D_linear_plus)=0.044164149310155984
# group
# D_linear_minus=0.11019356601806732
# (D_linear_minus + D_linear_plus)=0.22087376223191918
# (D_linear_plus)=0.11068019621385185
# group
# (D_linear_minus + D_linear_plus)=0.2633974222262125
# (D_linear_plus)=0.1093756835980225
# group
# D_linear_minus=0.04406650075629132
# (D_linear_minus + D_linear_plus)=0.08853065764362247
# (D_linear_plus)=0.04446415688733116
# group
# D_linear_minus=0.11068019621385185
# (D_linear_minus + D_linear_plus)=0.22394022765483657
# (D_linear_plus)=0.11326003144098473
# group
# (D_linear_minus + D_linear_plus)=0.2710956043857851
# (D_linear_plus)=0.11328351124508775
# group
# D_linear_minus=0.04587750476839315
# (D_linear_minus + D_linear_plus)=0.0914830668227413
# (D_linear_plus)=0.04560556205434814
# group
# D_linear_minus=0.11326003144098473
# (D_linear_minus + D_linear_plus)=0.27107212458168206
# group
# (D_linear_minus + D_linear_plus)=0.26925166957858315
# (D_linear_plus)=0.11230226378903346
# group
# D_linear_minus=0.04538698074457341
# (D_linear_minus + D_linear_plus)=0.09121418468937914
# (D_linear_plus)=0.045827203944805724
# group
# (D_linear_minus + D_linear_plus)=0.26901117423631754
# (D_linear_plus)=0.11206176844676786
# group
# (D_linear_minus + D_linear_plus)=0.2609437208347215
# (D_linear_plus)=0.10832252816114926
# group
# D_linear_minus=0.04403026640512689
# (D_linear_minus + D_linear_plus)=0.08829191026044886
# (D_linear_plus)=0.04426164385532196
# group
# D_linear_minus=0.11206176844676786
# (D_linear_minus + D_linear_plus)=0.22235377757012284
# (D_linear_plus)=0.11029200912335498
# group
# (D_linear_minus + D_linear_plus)=0.2629332124162298
# (D_linear_plus)=0.10943349562320734
# group
# D_linear_minus=0.044164149310155984
# (D_linear_minus + D_linear_plus)=0.08844696149014347
# (D_linear_plus)=0.04428281217998749
# group
# D_linear_minus=0.11029200912335498
# (D_linear_minus + D_linear_plus)=0.2211802349006537
# (D_linear_plus)=0.11088822577729872
# group
# (D_linear_minus + D_linear_plus)=0.26307063580084294
# (D_linear_plus)=0.10930538613220706
# group
# D_linear_minus=0.04446415688733116
# (D_linear_minus + D_linear_plus)=0.08892920347002559
# (D_linear_plus)=0.04446504658269443
# group
# D_linear_minus=0.11088822577729872
# (D_linear_minus + D_linear_plus)=0.22277471022563683
# (D_linear_plus)=0.1118864844483381
# group
# (D_linear_minus + D_linear_plus)=0.2671223733582545
# (D_linear_plus)=0.11170313774113914
# group
# D_linear_minus=0.04560556205434814
# (D_linear_minus + D_linear_plus)=0.09083488603425728
# (D_linear_plus)=0.04522932397990914
# group
# D_linear_minus=0.1118864844483381
# (D_linear_minus + D_linear_plus)=0.2673057200654535
# group
# (D_linear_minus + D_linear_plus)=0.27061720735713624
# (D_linear_plus)=0.11330931175924039
# group
# D_linear_minus=0.045827203944805724
# (D_linear_minus + D_linear_plus)=0.09190017431527847
# (D_linear_plus)=0.04607297037047274
# group
# (D_linear_minus + D_linear_plus)=0.27040499171685595
# (D_linear_plus)=0.11309709611896004
# group
# (D_linear_minus + D_linear_plus)=0.26439484209162484
# (D_linear_plus)=0.11019283746556473
# group
# D_linear_minus=0.04426164385532196
# (D_linear_minus + D_linear_plus)=0.0888282006654261
# (D_linear_plus)=0.04456655681010413
# group
# D_linear_minus=0.11309709611896004
# (D_linear_minus + D_linear_plus)=0.22416896183751725
# (D_linear_plus)=0.1110718657185572
# group
# (D_linear_minus + D_linear_plus)=0.2625578147868977
# (D_linear_plus)=0.10914075665103772
# group
# D_linear_minus=0.04428281217998749
# (D_linear_minus + D_linear_plus)=0.08823238444077547
# (D_linear_plus)=0.043949572260787974
# group
# D_linear_minus=0.1110718657185572
# (D_linear_minus + D_linear_plus)=0.22205238974639557
# (D_linear_plus)=0.11098052402783835
# group
# (D_linear_minus + D_linear_plus)=0.26399309568275686
# (D_linear_plus)=0.10996708685090552
# group
# D_linear_minus=0.04446504658269443
# (D_linear_minus + D_linear_plus)=0.08874227071068216
# (D_linear_plus)=0.04427722412798774
# group
# D_linear_minus=0.11098052402783835
# (D_linear_minus + D_linear_plus)=0.2233145785458017
# (D_linear_plus)=0.11233405451796334
# group
# (D_linear_minus + D_linear_plus)=0.26813140011831604
# (D_linear_plus)=0.11211566749183796
# group
# D_linear_minus=0.04522932397990914
# (D_linear_minus + D_linear_plus)=0.09069167035979933
# (D_linear_plus)=0.04546234637989018
# group
# D_linear_minus=0.11233405451796334
# (D_linear_minus + D_linear_plus)=0.2683497871444414
# group
# (D_linear_minus + D_linear_plus)=0.2714167745559269
# (D_linear_plus)=0.1133120080134252
# group
# D_linear_minus=0.04607297037047274
# (D_linear_minus + D_linear_plus)=0.09189403225067129
# (D_linear_plus)=0.04582106188019855
# group
# (D_linear_minus + D_linear_plus)=0.2715444155148519
# (D_linear_plus)=0.11343964897235022
# group
# (D_linear_minus + D_linear_plus)=0.26381992169230906
# (D_linear_plus)=0.10974478849435637
# group
# D_linear_minus=0.04456655681010413
# (D_linear_minus + D_linear_plus)=0.0888279068034096
# (D_linear_plus)=0.04426134999330547
# group
# D_linear_minus=0.11343964897235022
# (D_linear_minus + D_linear_plus)=0.22365070314108337
# (D_linear_plus)=0.11021105416873314
# group
# (D_linear_minus + D_linear_plus)=0.26011940939846206
# (D_linear_plus)=0.10821667575686743
# group
# D_linear_minus=0.043949572260787974
# (D_linear_minus + D_linear_plus)=0.08789494376946555
# (D_linear_plus)=0.04394537150867757
# group
# D_linear_minus=0.11021105416873314
# (D_linear_minus + D_linear_plus)=0.21980321789065838
# (D_linear_plus)=0.10959216372192525
# group
# (D_linear_minus + D_linear_plus)=0.2623035593055271
# (D_linear_plus)=0.10943529200618966
# group
# D_linear_minus=0.04427722412798774
# (D_linear_minus + D_linear_plus)=0.08877150216383234
# (D_linear_plus)=0.04449427803584459
# group
# D_linear_minus=0.10959216372192525
# (D_linear_minus + D_linear_plus)=0.22156847849182512
# (D_linear_plus)=0.11197631476989987
# group
# (D_linear_minus + D_linear_plus)=0.26938584418069245
# (D_linear_plus)=0.1128638872805785
# group
# D_linear_minus=0.04546234637989018
# (D_linear_minus + D_linear_plus)=0.09114838506911205
# (D_linear_plus)=0.045686038689221865
# group
# D_linear_minus=0.11197631476989987
# (D_linear_minus + D_linear_plus)=0.26849827167001383
# group
# (D_linear_minus + D_linear_plus)=0.2680949719839199
# (D_linear_plus)=0.11195939009002655
# group
# D_linear_minus=0.04582106188019855
# (D_linear_minus + D_linear_plus)=0.09164795080727652
# (D_linear_plus)=0.045826888927077966
# group
# (D_linear_minus + D_linear_plus)=0.2678477042231358
# (D_linear_plus)=0.11171212232924244
# group
# (D_linear_minus + D_linear_plus)=0.26171377736689805
# (D_linear_plus)=0.10896949725832744
# group
# D_linear_minus=0.04426134999330547
# (D_linear_minus + D_linear_plus)=0.08842476788854323
# (D_linear_plus)=0.04416341789523775
# group
# D_linear_minus=0.11171212232924244
# (D_linear_minus + D_linear_plus)=0.2220150804339729
# (D_linear_plus)=0.11030295810473044
# group
# (D_linear_minus + D_linear_plus)=0.2627381834163374
# (D_linear_plus)=0.10934159955825995
# group
# D_linear_minus=0.04394537150867757
# (D_linear_minus + D_linear_plus)=0.08799774978644984
# (D_linear_plus)=0.04405237827777227
# group
# D_linear_minus=0.11030295810473044
# (D_linear_minus + D_linear_plus)=0.22181812584027
# (D_linear_plus)=0.11151516773553956
# group
# (D_linear_minus + D_linear_plus)=0.2650925771676941
# (D_linear_plus)=0.11001390575768777
# group
# D_linear_minus=0.04449427803584459
# (D_linear_minus + D_linear_plus)=0.08898335985905165
# (D_linear_plus)=0.044489081823207065
# group
# D_linear_minus=0.11151516773553956
# (D_linear_minus + D_linear_plus)=0.22495983566597982
# (D_linear_plus)=0.11344466793044027
# group
# (D_linear_minus + D_linear_plus)=0.27064520352001553
# (D_linear_plus)=0.11357376900231123
# group
# D_linear_minus=0.045686038689221865
# (D_linear_minus + D_linear_plus)=0.09134610633461207
# (D_linear_plus)=0.04566006764539021
# group
# D_linear_minus=0.11344466793044027
# (D_linear_minus + D_linear_plus)=0.27051610244814456
# group
# (D_linear_minus + D_linear_plus)=0.27052717631960227
# (D_linear_plus)=0.1123946581066895
# group
# D_linear_minus=0.045826888927077966
# (D_linear_minus + D_linear_plus)=0.09197336939269596
# (D_linear_plus)=0.046146480465617985
# group
# (D_linear_minus + D_linear_plus)=0.2713290874512923
# (D_linear_plus)=0.11319656923837952
# group
# (D_linear_minus + D_linear_plus)=0.2634577764530089
# (D_linear_plus)=0.10985691137293675
# group
# D_linear_minus=0.04416341789523775
# (D_linear_minus + D_linear_plus)=0.0883792664028976
# (D_linear_plus)=0.044215848507659854
# group
# D_linear_minus=0.11319656923837952
# (D_linear_minus + D_linear_plus)=0.22343277235078848
# (D_linear_plus)=0.11023620311240896
# group
# (D_linear_minus + D_linear_plus)=0.26105631435354837
# (D_linear_plus)=0.10864168559748039
# group
# D_linear_minus=0.04405237827777227
# (D_linear_minus + D_linear_plus)=0.0879266040347946
# (D_linear_plus)=0.043874225757022337
# group
# D_linear_minus=0.11023620311240896
# (D_linear_minus + D_linear_plus)=0.22008189188881588
# (D_linear_plus)=0.10984568877640691
# group
# (D_linear_minus + D_linear_plus)=0.2618164375222174
# (D_linear_plus)=0.10897270342751846
# group
# D_linear_minus=0.044489081823207065
# (D_linear_minus + D_linear_plus)=0.08845430533141208
# (D_linear_plus)=0.04396522350820502
# group
# D_linear_minus=0.10984568877640691
# (D_linear_minus + D_linear_plus)=0.22174644623263412
# (D_linear_plus)=0.11190075745622723
# group
# (D_linear_minus + D_linear_plus)=0.2685108117306647
# (D_linear_plus)=0.11211076543625102
# group
# D_linear_minus=0.04566006764539021
# (D_linear_minus + D_linear_plus)=0.09145783614911987
# (D_linear_plus)=0.04579776850372966
# group
# D_linear_minus=0.11190075745622723
# (D_linear_minus + D_linear_plus)=0.2683008037506409
# group
# (D_linear_minus + D_linear_plus)=0.2708402392522615
# (D_linear_plus)=0.11321694631252405
# group
# D_linear_minus=0.046146480465617985
# (D_linear_minus + D_linear_plus)=0.09241707087835166
# (D_linear_plus)=0.04627059041273367
# group
# (D_linear_minus + D_linear_plus)=0.27023095994535323
# (D_linear_plus)=0.11260766700561575
# group
# (D_linear_minus + D_linear_plus)=0.2620713791999464
# (D_linear_plus)=0.10907611440339182
# group
# D_linear_minus=0.044215848507659854
# (D_linear_minus + D_linear_plus)=0.08835938120422274
# (D_linear_plus)=0.04414353269656288
# group
# D_linear_minus=0.11260766700561575
# (D_linear_minus + D_linear_plus)=0.22259362179918862
# (D_linear_plus)=0.10998595479357286
# group
# (D_linear_minus + D_linear_plus)=0.26115044402107135
# (D_linear_plus)=0.10861655099003986
# group
# D_linear_minus=0.043874225757022337
# (D_linear_minus + D_linear_plus)=0.08799862125280404
# (D_linear_plus)=0.044124395495781704
# group
# D_linear_minus=0.10998595479357286
# (D_linear_minus + D_linear_plus)=0.21973869285000552
# (D_linear_plus)=0.10975273805643267
# group
# (D_linear_minus + D_linear_plus)=0.26134136265815844
# (D_linear_plus)=0.10879699894358115
# group
# D_linear_minus=0.04396522350820502
# (D_linear_minus + D_linear_plus)=0.0881015960721531
# (D_linear_plus)=0.04413637256394808
# group
# D_linear_minus=0.10975273805643267
# (D_linear_minus + D_linear_plus)=0.22216710641133836
# (D_linear_plus)=0.11241436835490567
# group
# (D_linear_minus + D_linear_plus)=0.270972852205083
# (D_linear_plus)=0.11324887232435384
# group
# D_linear_minus=0.04579776850372966
# (D_linear_minus + D_linear_plus)=0.0918400330004244
# (D_linear_plus)=0.04604226449669475
# group
# D_linear_minus=0.11241436835490567
# (D_linear_minus + D_linear_plus)=0.2701383482356348
# group
# (D_linear_minus + D_linear_plus)=0.27207854080257277
# (D_linear_plus)=0.11336249016580398
# group
# D_linear_minus=0.04627059041273367
# (D_linear_minus + D_linear_plus)=0.09245863348308382
# (D_linear_plus)=0.046188043070350154
# group
# (D_linear_minus + D_linear_plus)=0.2720207405444935
# (D_linear_plus)=0.11330468990772467
# group
# (D_linear_minus + D_linear_plus)=0.2623516843389574
# (D_linear_plus)=0.10909967673765783
# group
# D_linear_minus=0.04414353269656288
# (D_linear_minus + D_linear_plus)=0.08848348265892936
# (D_linear_plus)=0.04433994996236647
# group
# D_linear_minus=0.11330468990772467
# (D_linear_minus + D_linear_plus)=0.2239907664847799
# (D_linear_plus)=0.11068607657705522
# group
# (D_linear_minus + D_linear_plus)=0.2628851765427211
# (D_linear_plus)=0.10926024260144267
# group
# D_linear_minus=0.044124395495781704
# (D_linear_minus + D_linear_plus)=0.08835931387682792
# (D_linear_plus)=0.04423491838104622
# group
# D_linear_minus=0.11068607657705522
# (D_linear_minus + D_linear_plus)=0.22159127370549783
# (D_linear_plus)=0.11090519712844261
# group
# (D_linear_minus + D_linear_plus)=0.26274921410461405
# (D_linear_plus)=0.10907682826398771
# group
# D_linear_minus=0.04413637256394808
# (D_linear_minus + D_linear_plus)=0.08849520446282769
# (D_linear_plus)=0.044358831898879604
# group
# D_linear_minus=0.11090519712844261
# (D_linear_minus + D_linear_plus)=0.22383791294568586
# (D_linear_plus)=0.11293271581724325
# group
# (D_linear_minus + D_linear_plus)=0.27077131965445445
# (D_linear_plus)=0.11322848375737402
# group
# D_linear_minus=0.04604226449669475
# (D_linear_minus + D_linear_plus)=0.09242359322900028
# (D_linear_plus)=0.04638132873230553
# group
# D_linear_minus=0.11293271581724325
# (D_linear_minus + D_linear_plus)=0.27047555171432364
# group
# (D_linear_minus + D_linear_plus)=0.2704430886692772
# (D_linear_plus)=0.11320272003495699
# group
# D_linear_minus=0.046188043070350154
# (D_linear_minus + D_linear_plus)=0.0921660058327981
# (D_linear_plus)=0.045977962762447956
# group
# (D_linear_minus + D_linear_plus)=0.27016198973711275
# (D_linear_plus)=0.11292162110279255
# group
# (D_linear_minus + D_linear_plus)=0.26364606873078356
# (D_linear_plus)=0.10970541900887734
# group
# D_linear_minus=0.04433994996236647
# (D_linear_minus + D_linear_plus)=0.08854744224815908
# (D_linear_plus)=0.044207492285792606
# group
# D_linear_minus=0.11292162110279255
# (D_linear_minus + D_linear_plus)=0.22367242293859785
# (D_linear_plus)=0.1107508018358053
# group
# (D_linear_minus + D_linear_plus)=0.26187142688595344
# (D_linear_plus)=0.10880871862500599
# group
# D_linear_minus=0.04423491838104622
# (D_linear_minus + D_linear_plus)=0.08870634215591408
# (D_linear_plus)=0.04447142377486787
# group
# D_linear_minus=0.1107508018358053
# (D_linear_minus + D_linear_plus)=0.2213300268744804
# (D_linear_plus)=0.11057922503867508
# group
# (D_linear_minus + D_linear_plus)=0.2630263307775071
# (D_linear_plus)=0.1094169716664752
# group
# D_linear_minus=0.044358831898879604
# (D_linear_minus + D_linear_plus)=0.0885518182509806
# (D_linear_plus)=0.04419298635210099
# group
# D_linear_minus=0.11057922503867508
# (D_linear_minus + D_linear_plus)=0.22438759450616574
# (D_linear_plus)=0.11380836946749065
# group
# (D_linear_minus + D_linear_plus)=0.27355612890830705
# (D_linear_plus)=0.11423623367707016
# group
# D_linear_minus=0.04638132873230553
# (D_linear_minus + D_linear_plus)=0.09272541737000947
# (D_linear_plus)=0.04634408863770394
# group
# D_linear_minus=0.11380836946749065
# (D_linear_minus + D_linear_plus)=0.27312826469872753
# group
# (D_linear_minus + D_linear_plus)=0.27015386967064003
# (D_linear_plus)=0.11242839716455581
# group
# D_linear_minus=0.045977962762447956
# (D_linear_minus + D_linear_plus)=0.12379700624967493
# group
# (D_linear_minus + D_linear_plus)=0.2701815584045409
# (D_linear_plus)=0.11245608589845665
# group
# (D_linear_minus + D_linear_plus)=0.2612512130368353
# (D_linear_plus)=0.10863141794417215
# group
# D_linear_minus=0.044207492285792606
# (D_linear_minus + D_linear_plus)=0.11894269611671915
# group
# D_linear_minus=0.11245608589845665
# (D_linear_minus + D_linear_plus)=0.22340077996846278
# (D_linear_plus)=0.11094469407000612
# group
# (D_linear_minus + D_linear_plus)=0.2645109556495609
# (D_linear_plus)=0.10974262063183218
# group
# D_linear_minus=0.04447142377486787
# (D_linear_minus + D_linear_plus)=0.12049869475696914
# group
# D_linear_minus=0.11094469407000612
# (D_linear_minus + D_linear_plus)=0.22202544310971306
# (D_linear_plus)=0.11108074903970692
# group
# (D_linear_minus + D_linear_plus)=0.26244829100035727
# (D_linear_plus)=0.10957090936184806
# group
# D_linear_minus=0.04419298635210099
# (D_linear_minus + D_linear_plus)=0.11908266449498675
# group
# D_linear_minus=0.11108074903970692
# (D_linear_minus + D_linear_plus)=0.22349587561913947
# (D_linear_plus)=0.11241512657943253
# group
# (D_linear_minus + D_linear_plus)=0.26985519049749107
# (D_linear_plus)=0.11248416785337463
# group
# D_linear_minus=0.04634408863770394
# (D_linear_minus + D_linear_plus)=0.12394753888710203
# group
# D_linear_minus=0.11241512657943253
# (D_linear_minus + D_linear_plus)=0.269786149223549
# group
# D_linear_minus=0.11172597640123925
# (D_linear_minus + D_linear_plus)=0.22293383835224773
# (D_linear_plus)=0.11120786195100847
# group
# (D_linear_minus + D_linear_plus)=0.11942289314566995
# (D_linear_plus)=0.04430665076057904
# group
# (D_linear_minus + D_linear_plus)=0.2626215380483227
# (D_linear_plus)=0.10936671205385216
# group
# D_linear_minus=0.10986994694380262
# (D_linear_minus + D_linear_plus)=0.21814673272576135
# (D_linear_plus)=0.10827678578195872
# group
# (D_linear_minus + D_linear_plus)=0.11712103926854231
# (D_linear_plus)=0.04329946232892653
# group
# D_linear_minus=0.10936671205385216
# (D_linear_minus + D_linear_plus)=0.21807890738792474
# (D_linear_plus)=0.10871219533407256
# group
# D_linear_minus=0.109853652963522
# (D_linear_minus + D_linear_plus)=0.2186268651670062
# (D_linear_plus)=0.10877321220348421
# group
# (D_linear_minus + D_linear_plus)=0.11753994555154154
# (D_linear_plus)=0.043192299676813616
# group
# D_linear_minus=0.10871219533407256
# (D_linear_minus + D_linear_plus)=0.217697012659171
# (D_linear_plus)=0.10898481732509843
# group
# D_linear_minus=0.10947410827865103
# (D_linear_minus + D_linear_plus)=0.217382847699548
# (D_linear_plus)=0.10790873942089696
# group
# (D_linear_minus + D_linear_plus)=0.11747259709103226
# (D_linear_plus)=0.0433361935221058
# group
# D_linear_minus=0.10898481732509843
# (D_linear_minus + D_linear_plus)=0.21856869446842211
# (D_linear_plus)=0.10958387714332368
# group
# D_linear_minus=0.11281079373674475
# (D_linear_minus + D_linear_plus)=0.22189297625305254
# (D_linear_plus)=0.10908218251630779
# group
# (D_linear_minus + D_linear_plus)=0.11908762800011413
# (D_linear_plus)=0.04404030127970106
# group
# D_linear_minus=0.10958387714332368
# (D_linear_minus + D_linear_plus)=0.2627239375111355
# group
# D_linear_minus=0.11269332539972322
# (D_linear_minus + D_linear_plus)=0.22291713484480147
# (D_linear_plus)=0.11022380944507823
# group
# D_linear_minus=0.04430665076057904
# (D_linear_minus + D_linear_plus)=0.08879291229086195
# (D_linear_plus)=0.0444862615302829
# group
# (D_linear_minus + D_linear_plus)=0.26339722379702335
# (D_linear_plus)=0.1096199148691741
# group
# D_linear_minus=0.10926274959709362
# (D_linear_minus + D_linear_plus)=0.21675079692623062
# (D_linear_plus)=0.10748804732913698
# group
# D_linear_minus=0.04329946232892653
# (D_linear_minus + D_linear_plus)=0.08658149563228706
# (D_linear_plus)=0.04328203330336053
# group
# D_linear_minus=0.1096199148691741
# (D_linear_minus + D_linear_plus)=0.21714332809240344
# (D_linear_plus)=0.10752341322322935
# group
# D_linear_minus=0.10828452408410244
# (D_linear_minus + D_linear_plus)=0.21527507253905193
# (D_linear_plus)=0.10699054845494947
# group
# D_linear_minus=0.043192299676813616
# (D_linear_minus + D_linear_plus)=0.08620013893071363
# (D_linear_plus)=0.043007839253900004
# group
# D_linear_minus=0.10752341322322935
# (D_linear_minus + D_linear_plus)=0.214871612135148
# (D_linear_plus)=0.10734819891191866
# group
# D_linear_minus=0.10960513653511857
# (D_linear_minus + D_linear_plus)=0.21754567425170124
# (D_linear_plus)=0.10794053771658269
# group
# D_linear_minus=0.0433361935221058
# (D_linear_minus + D_linear_plus)=0.08660460260760634
# (D_linear_plus)=0.043268409085500545
# group
# D_linear_minus=0.10734819891191866
# (D_linear_minus + D_linear_plus)=0.21619386881347863
# (D_linear_plus)=0.10884566990155999
# group
# D_linear_minus=0.11250390951085551
# (D_linear_minus + D_linear_plus)=0.22161572839396512
# (D_linear_plus)=0.10911181888310961
# group
# D_linear_minus=0.04404030127970106
# (D_linear_minus + D_linear_plus)=0.08816995419998085
# (D_linear_plus)=0.04412965292027979
# group
# D_linear_minus=0.10884566990155999
# (D_linear_minus + D_linear_plus)=0.2614563813421746
# group
# D_linear_minus=0.11220095640095235
# (D_linear_minus + D_linear_plus)=0.22241966338121327
# (D_linear_plus)=0.11021870698026091
# group
# D_linear_minus=0.0444862615302829
# (D_linear_minus + D_linear_plus)=0.08908516685015182
# (D_linear_plus)=0.04459890531986892
# group
# (D_linear_minus + D_linear_plus)=0.2638753423509937
# (D_linear_plus)=0.10975960451419302
# group
# D_linear_minus=0.10940619786110882
# (D_linear_minus + D_linear_plus)=0.2174023402389031
# (D_linear_plus)=0.10799614237779427
# group
# D_linear_minus=0.04328203330336053
# (D_linear_minus + D_linear_plus)=0.08660372393233733
# (D_linear_plus)=0.0433216906289768
# group
# D_linear_minus=0.10975960451419302
# (D_linear_minus + D_linear_plus)=0.21796082415834084
# (D_linear_plus)=0.10820121964414783
# group
# D_linear_minus=0.10864097742114567
# (D_linear_minus + D_linear_plus)=0.21666791934046037
# (D_linear_plus)=0.10802694191931468
# group
# D_linear_minus=0.043007839253900004
# (D_linear_minus + D_linear_plus)=0.08616574648382053
# (D_linear_plus)=0.04315790722992052
# group
# D_linear_minus=0.10820121964414783
# (D_linear_minus + D_linear_plus)=0.2165462813304087
# (D_linear_plus)=0.10834506168626089
# group
# D_linear_minus=0.11036065863241074
# (D_linear_minus + D_linear_plus)=0.21911541665307416
# (D_linear_plus)=0.10875475802066342
# group
# D_linear_minus=0.043268409085500545
# (D_linear_minus + D_linear_plus)=0.08654805401929351
# (D_linear_plus)=0.043279644933792966
# group
# D_linear_minus=0.10834506168626089
# (D_linear_minus + D_linear_plus)=0.21797615306377555
# (D_linear_plus)=0.10963109137751467
# group
# D_linear_minus=0.11242043443752683
# (D_linear_minus + D_linear_plus)=0.2231094514305047
# (D_linear_plus)=0.11068901699297787
# group
# D_linear_minus=0.04412965292027979
# (D_linear_minus + D_linear_plus)=0.0882822487065768
# (D_linear_plus)=0.044152595786297016
# group
# D_linear_minus=0.10963109137751467
# (D_linear_minus + D_linear_plus)=0.26320364980419453
# group
# D_linear_minus=0.11276347185198216
# (D_linear_minus + D_linear_plus)=0.22338673437536516
# (D_linear_plus)=0.11062326252338299
# group
# D_linear_minus=0.04459890531986892
# (D_linear_minus + D_linear_plus)=0.08931747459396355
# (D_linear_plus)=0.04471856927409464
# group
# (D_linear_minus + D_linear_plus)=0.26431197897176556
# (D_linear_plus)=0.10999575416388926
# group
# D_linear_minus=0.10882683582710029
# (D_linear_minus + D_linear_plus)=0.2173012944310774
# (D_linear_plus)=0.10847445860397711
# group
# D_linear_minus=0.0433216906289768
# (D_linear_minus + D_linear_plus)=0.08644818927480474
# (D_linear_plus)=0.04312649864582794
# group
# D_linear_minus=0.10999575416388926
# (D_linear_minus + D_linear_plus)=0.21799294623689536
# (D_linear_plus)=0.1079971920730061
# group
# D_linear_minus=0.10861371965061138
# (D_linear_minus + D_linear_plus)=0.21644008039232734
# (D_linear_plus)=0.10782636074171596
# group
# D_linear_minus=0.04315790722992052
# (D_linear_minus + D_linear_plus)=0.08612929258441296
# (D_linear_plus)=0.04297138535449244
# group
# D_linear_minus=0.1079971920730061
# (D_linear_minus + D_linear_plus)=0.21574722062676369
# (D_linear_plus)=0.10775002855375758
# group
# D_linear_minus=0.10923303119476904
# (D_linear_minus + D_linear_plus)=0.2169099659339324
# (D_linear_plus)=0.10767693473916339
# group
# D_linear_minus=0.043279644933792966
# (D_linear_minus + D_linear_plus)=0.08639735736667754
# (D_linear_plus)=0.04311771243288458
# group
# D_linear_minus=0.10775002855375758
# (D_linear_minus + D_linear_plus)=0.21667999856533685
# (D_linear_plus)=0.10892997001157927
# group
# D_linear_minus=0.11147899178399831
# (D_linear_minus + D_linear_plus)=0.22180312408469777
# (D_linear_plus)=0.11032413230069946
# group
# D_linear_minus=0.044152595786297016
# (D_linear_minus + D_linear_plus)=0.08843687874072295
# (D_linear_plus)=0.044284282954425935
# group
# D_linear_minus=0.10892997001157927
# (D_linear_minus + D_linear_plus)=0.26165045639578427
# group
# D_linear_minus=0.11264001153433717
# (D_linear_minus + D_linear_plus)=0.22395594396111357
# (D_linear_plus)=0.11131593242677638
# group
# D_linear_minus=0.04471856927409464
# (D_linear_minus + D_linear_plus)=0.08892987277806151
# (D_linear_plus)=0.04421130350396687
# group
# (D_linear_minus + D_linear_plus)=0.2642335969857563
# (D_linear_plus)=0.10954570301502639
# group
# D_linear_minus=0.10910610459565824
# (D_linear_minus + D_linear_plus)=0.21659969797749268
# (D_linear_plus)=0.10749359338183445
# group
# D_linear_minus=0.04312649864582794
# (D_linear_minus + D_linear_plus)=0.08607864244101493
# (D_linear_plus)=0.042952143795187
# group
# D_linear_minus=0.10954570301502639
# (D_linear_minus + D_linear_plus)=0.21679512011444446
# (D_linear_plus)=0.10724941709941807
# group
# D_linear_minus=0.1093537956155689
# (D_linear_minus + D_linear_plus)=0.21698761674537959
# (D_linear_plus)=0.1076338211298107
# group
# D_linear_minus=0.04297138535449244
# (D_linear_minus + D_linear_plus)=0.08599879381368095
# (D_linear_plus)=0.043027408459188496
# group
# D_linear_minus=0.10724941709941807
# (D_linear_minus + D_linear_plus)=0.21472186922312744
# (D_linear_plus)=0.10747245212370937
# group
# D_linear_minus=0.10961270542791157
# (D_linear_minus + D_linear_plus)=0.2170515566057637
# (D_linear_plus)=0.10743885117785212
# group
# D_linear_minus=0.04311771243288458
# (D_linear_minus + D_linear_plus)=0.08621159460990131
# (D_linear_plus)=0.043093882177016735
# group
# D_linear_minus=0.10747245212370937
# (D_linear_minus + D_linear_plus)=0.21701023553903173
# (D_linear_plus)=0.10953778341532236
# group
# D_linear_minus=0.11364850336285921
# (D_linear_minus + D_linear_plus)=0.22461240236795688
# (D_linear_plus)=0.11096389900509768
# group
# D_linear_minus=0.044284282954425935
# (D_linear_minus + D_linear_plus)=0.0886277720553506
# (D_linear_plus)=0.04434348910092468
# group
# D_linear_minus=0.10953778341532236
# (D_linear_minus + D_linear_plus)=0.2637483486895704
# group
# D_linear_minus=0.11207834724786016
# (D_linear_minus + D_linear_plus)=0.22225224572922314
# (D_linear_plus)=0.11017389848136298
# group
# D_linear_minus=0.04421130350396687
# (D_linear_minus + D_linear_plus)=0.08802252969256544
# (D_linear_plus)=0.043811226188598576
# group
# (D_linear_minus + D_linear_plus)=0.26023463684394094
# (D_linear_plus)=0.10832428825526404
# group
# D_linear_minus=0.10935020825747163
# (D_linear_minus + D_linear_plus)=0.21667006650940285
# (D_linear_plus)=0.1073198582519312
# group
# D_linear_minus=0.042952143795187
# (D_linear_minus + D_linear_plus)=0.08621634094148056
# (D_linear_plus)=0.04326419714629356
# group
# D_linear_minus=0.10832428825526404
# (D_linear_minus + D_linear_plus)=0.21602453262711852
# (D_linear_plus)=0.10770024437185448
# group
# D_linear_minus=0.10863106392177692
# (D_linear_minus + D_linear_plus)=0.21607684141016742
# (D_linear_plus)=0.10744577748839049
# group
# D_linear_minus=0.043027408459188496
# (D_linear_minus + D_linear_plus)=0.08632799572340327
# (D_linear_plus)=0.04330058726421477
# group
# D_linear_minus=0.10770024437185448
# (D_linear_minus + D_linear_plus)=0.21553148847483333
# (D_linear_plus)=0.10783124410297885
# group
# D_linear_minus=0.1092276621238882
# (D_linear_minus + D_linear_plus)=0.2170306586159787
# (D_linear_plus)=0.1078029964920905
# group
# D_linear_minus=0.043093882177016735
# (D_linear_minus + D_linear_plus)=0.08618665013323448
# (D_linear_plus)=0.04309276795621775
# group
# D_linear_minus=0.10783124410297885
# (D_linear_minus + D_linear_plus)=0.21684350580217476
# (D_linear_plus)=0.10901226169919592
# group
# D_linear_minus=0.11148272017837235
# (D_linear_minus + D_linear_plus)=0.2219135772101676
# (D_linear_plus)=0.11043085703179525
# group
# D_linear_minus=0.04434348910092468
# (D_linear_minus + D_linear_plus)=0.08828581918691983
# (D_linear_plus)=0.04394233008599515
# group
# D_linear_minus=0.10901226169919592
# (D_linear_minus + D_linear_plus)=0.2620145490833923
# group
# D_linear_minus=0.11183243028645876
# (D_linear_minus + D_linear_plus)=0.2221310085377851
# (D_linear_plus)=0.11029857825132634
# group
# D_linear_minus=0.043811226188598576
# (D_linear_minus + D_linear_plus)=0.08807287004392055
# (D_linear_plus)=0.04426164385532197
# group
# (D_linear_minus + D_linear_plus)=0.26209649372140753
# (D_linear_plus)=0.1093606122444516
# group
# D_linear_minus=0.10959684799465166
# (D_linear_minus + D_linear_plus)=0.21821092155461913
# (D_linear_plus)=0.10861407355996745
# group
# D_linear_minus=0.04326419714629356
# (D_linear_minus + D_linear_plus)=0.08659349002306613
# (D_linear_plus)=0.04332929287677258
# group
# D_linear_minus=0.1093606122444516
# (D_linear_minus + D_linear_plus)=0.21807706234794966
# (D_linear_plus)=0.10871645010349808
# group
# D_linear_minus=0.10905113516779154
# (D_linear_minus + D_linear_plus)=0.2174719641100813
# (D_linear_plus)=0.10842082894228977
# group
# D_linear_minus=0.04330058726421477
# (D_linear_minus + D_linear_plus)=0.08673489450330217
# (D_linear_plus)=0.0434343072390874
# group
# D_linear_minus=0.10871645010349808
# (D_linear_minus + D_linear_plus)=0.2168678187590684
# (D_linear_plus)=0.10815136865557035
# group
# D_linear_minus=0.10949172844737445
# (D_linear_minus + D_linear_plus)=0.21733553179635595
# (D_linear_plus)=0.10784380334898148
# group
# D_linear_minus=0.04309276795621775
# (D_linear_minus + D_linear_plus)=0.08629878396188637
# (D_linear_plus)=0.043206016005668625
# group
# D_linear_minus=0.10815136865557035
# (D_linear_minus + D_linear_plus)=0.21670707836023367
# (D_linear_plus)=0.10855570970466334
# group
# D_linear_minus=0.11171736400645281
# (D_linear_minus + D_linear_plus)=0.2216376717833146
# (D_linear_plus)=0.10992030777686178
# group
# D_linear_minus=0.04394233008599515
# (D_linear_minus + D_linear_plus)=0.08785022011429378
# (D_linear_plus)=0.04390789002829863
# group
# D_linear_minus=0.10855570970466334
# (D_linear_minus + D_linear_plus)=0.260832475772527
# group
# D_linear_minus=0.11274897793051505
# (D_linear_minus + D_linear_plus)=0.22284609459712668
# (D_linear_plus)=0.11009711666661162
# group
# D_linear_minus=0.04426164385532197
# (D_linear_minus + D_linear_plus)=0.08858965339470962
# (D_linear_plus)=0.044328009539387654
# group
# (D_linear_minus + D_linear_plus)=0.26367726800672386
# (D_linear_plus)=0.10959216372192525
# group
# D_linear_minus=0.10970686326136564
# (D_linear_minus + D_linear_plus)=0.21784068968494746
# (D_linear_plus)=0.10813382642358182
# group
# D_linear_minus=0.04332929287677258
# (D_linear_minus + D_linear_plus)=0.08652900948663161
# (D_linear_plus)=0.043199716609859044
# group
# D_linear_minus=0.10959216372192525
# (D_linear_minus + D_linear_plus)=0.2177856569652416
# (D_linear_plus)=0.10819349324331635
# group
# D_linear_minus=0.10947231062111305
# (D_linear_minus + D_linear_plus)=0.21767036933154366
# (D_linear_plus)=0.10819805871043062
# group
# D_linear_minus=0.0434343072390874
# (D_linear_minus + D_linear_plus)=0.08674755405421022
# (D_linear_plus)=0.04331324681512282
# group
# D_linear_minus=0.10819349324331635
# (D_linear_minus + D_linear_plus)=0.21664183604419002
# (D_linear_plus)=0.10844834280087366
# group
# D_linear_minus=0.1102019450643304
# (D_linear_minus + D_linear_plus)=0.21833471913495622
# (D_linear_plus)=0.10813277407062584
# group
# D_linear_minus=0.043206016005668625
# (D_linear_minus + D_linear_plus)=0.08646656346789676
# (D_linear_plus)=0.043260547462228134
# group
# ...
# group
# D_linear_minus=0.04432727268697521
# (D_linear_minus + D_linear_plus)=0.08835957478379343
# (D_linear_plus)=0.04403230209681822
# group
# D_linear_minus=0.11035663955204034
# (D_linear_minus + D_linear_plus)=0.22124486532933907
# (D_linear_plus)=0.11088822577729875
# group
# D_linear_minus=0.10991632070504725
# (D_linear_minus + D_linear_plus)=0.2642582683769533
# group
# D_linear_minus=0.044540354674844275
# (D_linear_minus + D_linear_plus)=0.08912613604623604
# (D_linear_plus)=0.044585781371391756
# group
# D_linear_minus=0.11088822577729875
# (D_linear_minus + D_linear_plus)=0.22351720003144154
# (D_linear_plus)=0.11262897425414278
# group
# D_linear_minus=0.11192292539665484
# (D_linear_minus + D_linear_plus)=0.26818293580357155
# group
# D_linear_minus=0.04577182744021055
# (D_linear_minus + D_linear_plus)=0.091333909764059
# (D_linear_plus)=0.045562082323848445
# group
# D_linear_minus=0.11262897425414278
# (D_linear_minus + D_linear_plus)=0.2688889846610595
# group
# D_linear_minus=0.1126107104046666
# (D_linear_minus + D_linear_plus)=0.2700062548515944
# group
# D_linear_minus=0.045981451082633275
# (D_linear_minus + D_linear_plus)=0.09164276966736071
# (D_linear_plus)=0.04566131858472743
# group
# (D_linear_minus + D_linear_plus)=0.2702437658461103
# (D_linear_plus)=0.11284822139918252
# group
# D_linear_minus=0.10946763698780093
# (D_linear_minus + D_linear_plus)=0.2631237300665159
# group
# D_linear_minus=0.04429384537018582
# (D_linear_minus + D_linear_plus)=0.08875978168384853
# (D_linear_plus)=0.04446593631366271
# group
# D_linear_minus=0.11284822139918252
# (D_linear_minus + D_linear_plus)=0.22330505983727864
# (D_linear_plus)=0.11045683843809612
# group
# D_linear_minus=0.1084970553899167
# (D_linear_minus + D_linear_plus)=0.2612791407737129
# group
# D_linear_minus=0.04403230209681822
# (D_linear_minus + D_linear_plus)=0.08790205280695981
# (D_linear_plus)=0.04386975071014159
# group
# D_linear_minus=0.11045683843809612
# (D_linear_minus + D_linear_plus)=0.22110543840136077
# (D_linear_plus)=0.11064859996326465
# group
# D_linear_minus=0.1094568532030359
# (D_linear_minus + D_linear_plus)=0.263484285488726
# group
# D_linear_minus=0.044585781371391756
# (D_linear_minus + D_linear_plus)=0.0890259299348084
# (D_linear_plus)=0.044440148563416645
# group
# D_linear_minus=0.11064859996326465
# (D_linear_minus + D_linear_plus)=0.22336288390632592
# (D_linear_plus)=0.11271428394306125
# group
# D_linear_minus=0.11338099870518899
# (D_linear_minus + D_linear_plus)=0.27012965536920136
# group
# D_linear_minus=0.045562082323848445
# (D_linear_minus + D_linear_plus)=0.09142506894446867
# (D_linear_plus)=0.04586298662062023
# group
# D_linear_minus=0.11271428394306125
# (D_linear_minus + D_linear_plus)=0.26946294060707365
# group
# D_linear_minus=0.11208060837354225
# (D_linear_minus + D_linear_plus)=0.2681664743301223
# group
# D_linear_minus=0.04566131858472743
# (D_linear_minus + D_linear_plus)=0.09116245099416029
# (D_linear_plus)=0.04550113240943285
# group
# (D_linear_minus + D_linear_plus)=0.26851691761415103
# (D_linear_plus)=0.112431051657571
# group
# D_linear_minus=0.10883678509197252
# (D_linear_minus + D_linear_plus)=0.262976753431623
# group
# D_linear_minus=0.04446593631366271
# (D_linear_minus + D_linear_plus)=0.08911277978182952
# (D_linear_plus)=0.0446468434681668
# group
# D_linear_minus=0.112431051657571
# (D_linear_minus + D_linear_plus)=0.22280340382484248
# (D_linear_plus)=0.1103723521672715
# group
# D_linear_minus=0.10881333616248008
# (D_linear_minus + D_linear_plus)=0.26095943293044055
# group
# D_linear_minus=0.04386975071014159
# (D_linear_minus + D_linear_plus)=0.08775047412774786
# (D_linear_plus)=0.043880723417606265
# group
# D_linear_minus=0.1103723521672715
# (D_linear_minus + D_linear_plus)=0.22049056406774664
# (D_linear_plus)=0.11011821190047516
# group
# D_linear_minus=0.10916291692047046
# (D_linear_minus + D_linear_plus)=0.2628076779414092
# group
# D_linear_minus=0.044440148563416645
# (D_linear_minus + D_linear_plus)=0.08888977879805512
# (D_linear_plus)=0.044449630234638486
# group
# D_linear_minus=0.11011821190047516
# (D_linear_minus + D_linear_plus)=0.2231060510193508
# (D_linear_plus)=0.11298783911887564
# group
# D_linear_minus=0.1125498736627668
# (D_linear_minus + D_linear_plus)=0.2702290879157063
# group
# D_linear_minus=0.04586298662062023
# (D_linear_minus + D_linear_plus)=0.09168562323221954
# (D_linear_plus)=0.04582263661159932
# group
# D_linear_minus=0.11298783911887564
# (D_linear_minus + D_linear_plus)=0.2706670533718152
# group
# D_linear_minus=0.11239806900117456
# (D_linear_minus + D_linear_plus)=0.2690332937570586
# group
# D_linear_minus=0.04550113240943285
# (D_linear_minus + D_linear_plus)=0.09135181736135269
# (D_linear_plus)=0.04585068495191984
# group
# (D_linear_minus + D_linear_plus)=0.2695549331971968
# (D_linear_plus)=0.11291970844131283
# group
# D_linear_minus=0.10968412070079378
# (D_linear_minus + D_linear_plus)=0.2642056525036428
# group
# D_linear_minus=0.0446468434681668
# (D_linear_minus + D_linear_plus)=0.0893372340286625
# (D_linear_plus)=0.0446903905604957
# group
# D_linear_minus=0.11291970844131283
# (D_linear_minus + D_linear_plus)=0.223851110680796
# (D_linear_plus)=0.11093140223948315
# group
# D_linear_minus=0.10839438647151341
# (D_linear_minus + D_linear_plus)=0.26122971099439973
# group
# D_linear_minus=0.043880723417606265
# (D_linear_minus + D_linear_plus)=0.08800643315206877
# (D_linear_plus)=0.04412570973446251
# group
# D_linear_minus=0.11093140223948315
# (D_linear_minus + D_linear_plus)=0.2216314471837014
# (D_linear_plus)=0.11070004494421824
# group
# D_linear_minus=0.10982180314222142
# (D_linear_minus + D_linear_plus)=0.2638947998466
# group
# D_linear_minus=0.044449630234638486
# (D_linear_minus + D_linear_plus)=0.08867882592671483
# (D_linear_plus)=0.04422919569207634
# group
# D_linear_minus=0.11070004494421824
# (D_linear_minus + D_linear_plus)=0.2233411983896295
# (D_linear_plus)=0.11264115344541129
# group
# D_linear_minus=0.1131043874322929
# (D_linear_minus + D_linear_plus)=0.26966457229855917
# group
# D_linear_minus=0.04582263661159932
# (D_linear_minus + D_linear_plus)=0.0914066821956449
# (D_linear_plus)=0.04558404558404558
# group
# D_linear_minus=0.11264115344541129
# (D_linear_minus + D_linear_plus)=0.2692013383116776
# group
# D_linear_minus=0.11265219311289552
# (D_linear_minus + D_linear_plus)=0.27038811478754626
# group
# D_linear_minus=0.04585068495191984
# (D_linear_minus + D_linear_plus)=0.09166718072305728
# (D_linear_plus)=0.045816495771137444
# group
# (D_linear_minus + D_linear_plus)=0.27113273454382825
# (D_linear_plus)=0.1133968128691775
# group
# D_linear_minus=0.10963181252083004
# (D_linear_minus + D_linear_plus)=0.26397947754935347
# group
# D_linear_minus=0.0446903905604957
# (D_linear_minus + D_linear_plus)=0.08928422434812872
# (D_linear_plus)=0.044593833787633014
# group
# D_linear_minus=0.1133968128691775
# (D_linear_minus + D_linear_plus)=0.2244968139801775
# (D_linear_plus)=0.111100001111
# group
# D_linear_minus=0.10912467821860511
# (D_linear_minus + D_linear_plus)=0.26245140828076374
# group
# D_linear_minus=0.04412570973446251
# (D_linear_minus + D_linear_plus)=0.0885293028732193
# (D_linear_plus)=0.044403593138756796
# group
# D_linear_minus=0.111100001111
# (D_linear_minus + D_linear_plus)=0.22128810322011047
# (D_linear_plus)=0.11018810210911047
# group
# D_linear_minus=0.10971914094301406
# (D_linear_minus + D_linear_plus)=0.26231238686076325
# group
# D_linear_minus=0.04422919569207634
# (D_linear_minus + D_linear_plus)=0.0884597118732578
# (D_linear_plus)=0.04423051618118145
# group
# D_linear_minus=0.11018810210911047
# (D_linear_minus + D_linear_plus)=0.22203178937179213
# (D_linear_plus)=0.11184368726268168
# group
# D_linear_minus=0.1128562448438803
# (D_linear_minus + D_linear_plus)=0.26940760621451876
# group
# D_linear_minus=0.04558404558404558
# (D_linear_minus + D_linear_plus)=0.09157675803875713
# (D_linear_plus)=0.04599271245471155
# group
# D_linear_minus=0.11184368726268168
# (D_linear_minus + D_linear_plus)=0.26839504863332014
# group
# D_linear_minus=0.11218962739580951
# (D_linear_minus + D_linear_plus)=0.2686652946471736
# group
# D_linear_minus=0.045816495771137444
# (D_linear_minus + D_linear_plus)=0.09127915217688257
# (D_linear_plus)=0.045462656405745115
# group
# (D_linear_minus + D_linear_plus)=0.26906621820196613
# (D_linear_plus)=0.11259055095060204
# group
# D_linear_minus=0.10946799648388796
# (D_linear_minus + D_linear_plus)=0.26352817547100393
# group
# D_linear_minus=0.044593833787633014
# (D_linear_minus + D_linear_plus)=0.08909375480027322
# (D_linear_plus)=0.044499921012640206
# group
# D_linear_minus=0.11259055095060204
# (D_linear_minus + D_linear_plus)=0.2239834861878634
# (D_linear_plus)=0.11139293523726138
# group
# D_linear_minus=0.10966030527235782
# (D_linear_minus + D_linear_plus)=0.2638323551130981
# group
# D_linear_minus=0.044403593138756796
# (D_linear_minus + D_linear_plus)=0.08877630170435352
# (D_linear_plus)=0.04437270856559672
# group
# D_linear_minus=0.11139293523726138
# (D_linear_minus + D_linear_plus)=0.22279592217414712
# (D_linear_plus)=0.11140298693688575
# group
# D_linear_minus=0.10933370944129381
# (D_linear_minus + D_linear_plus)=0.26341311580415694
# group
# D_linear_minus=0.04423051618118145
# (D_linear_minus + D_linear_plus)=0.08870639024329646
# (D_linear_plus)=0.044475874062115006
# group
# D_linear_minus=0.11140298693688575
# (D_linear_minus + D_linear_plus)=0.2250456784049334
# (D_linear_plus)=0.11364269146804765
# group
# D_linear_minus=0.11346436197854617
# (D_linear_minus + D_linear_plus)=0.2719592941030915
# group
# D_linear_minus=0.04599271245471155
# (D_linear_minus + D_linear_plus)=0.0920139996010811
# (D_linear_plus)=0.04602128714636955
# group
# D_linear_minus=0.11364269146804765
# (D_linear_minus + D_linear_plus)=0.27213762359259297
# group
# D_linear_minus=0.1118954985559886
# (D_linear_minus + D_linear_plus)=0.2679587103993136
# group
# D_linear_minus=0.045462656405745115
# (D_linear_minus + D_linear_plus)=0.09123244125342898
# (D_linear_plus)=0.04576978484768387
# group
# (D_linear_minus + D_linear_plus)=0.26835374788465693
# (D_linear_plus)=0.11229053604133189
# group
# D_linear_minus=0.10994278577428306
# (D_linear_minus + D_linear_plus)=0.26384079141002803
# group
# D_linear_minus=0.044499921012640206
# (D_linear_minus + D_linear_plus)=0.08854938856470117
# (D_linear_plus)=0.04404946755206096
# group
# D_linear_minus=0.11229053604133189
# (D_linear_minus + D_linear_plus)=0.22308035667261228
# (D_linear_plus)=0.11078982063128039
# group
# D_linear_minus=0.109302877179636
# (D_linear_minus + D_linear_plus)=0.26248234684167615
# group
# D_linear_minus=0.04437270856559672
# (D_linear_minus + D_linear_plus)=0.08843382132899955
# (D_linear_plus)=0.044061112763402834
# group
# D_linear_minus=0.11078982063128039
# (D_linear_minus + D_linear_plus)=0.22151008919436382
# (D_linear_plus)=0.11072026856308344
# group
# D_linear_minus=0.10973684008379504
# (D_linear_minus + D_linear_plus)=0.2635006711403986
# group
# D_linear_minus=0.044475874062115006
# (D_linear_minus + D_linear_plus)=0.08887089205319605
# (D_linear_plus)=0.044395017991081046
# group
# D_linear_minus=0.11072026856308344
# (D_linear_minus + D_linear_plus)=0.22325988250719175
# (D_linear_plus)=0.11253961394410833
# group
# D_linear_minus=0.11236434814070712
# (D_linear_minus + D_linear_plus)=0.2690481664626861
# group
# D_linear_minus=0.04602128714636955
# (D_linear_minus + D_linear_plus)=0.09163901967135667
# (D_linear_plus)=0.04561773252498712
# group
# D_linear_minus=0.11253961394410833
# (D_linear_minus + D_linear_plus)=0.2692234322660873
# group
# D_linear_minus=0.11222815535070176
# (D_linear_minus + D_linear_plus)=0.27016287461384153
# group
# D_linear_minus=0.04576978484768387
# (D_linear_minus + D_linear_plus)=0.091901257237421
# (D_linear_plus)=0.04613147238973713
# group
# (D_linear_minus + D_linear_plus)=0.2701099998696042
# (D_linear_plus)=0.11217528060646444
# group
# D_linear_minus=0.10855853802045677
# (D_linear_minus + D_linear_plus)=0.2604675020165132
# group
# D_linear_minus=0.04404946755206096
# (D_linear_minus + D_linear_plus)=0.08811596830835228
# (D_linear_plus)=0.044066500756291316
# group
# D_linear_minus=0.11217528060646444
# (D_linear_minus + D_linear_plus)=0.22166952668383305
# (D_linear_plus)=0.10949424607736861
# group
# D_linear_minus=0.10902224489884915
# (D_linear_minus + D_linear_plus)=0.26169376753774587
# group
# D_linear_minus=0.044061112763402834
# (D_linear_minus + D_linear_plus)=0.08811159902570806
# (D_linear_plus)=0.04405048626230523
# group
# D_linear_minus=0.10949424607736861
# (D_linear_minus + D_linear_plus)=0.21991156834688624
# (D_linear_plus)=0.11041732226951763
# group
# D_linear_minus=0.10959504630390705
# (D_linear_minus + D_linear_plus)=0.2632865628395773
# group
# D_linear_minus=0.044395017991081046
# (D_linear_minus + D_linear_plus)=0.08868312541631442
# (D_linear_plus)=0.04428810742523337
# group
# D_linear_minus=0.11041732226951763
# (D_linear_minus + D_linear_plus)=0.22286809694290435
# (D_linear_plus)=0.11245077467338672
# group
# D_linear_minus=0.1122530993080719
# (D_linear_minus + D_linear_plus)=0.2688397606299139
# group
# D_linear_minus=0.04561773252498712
# (D_linear_minus + D_linear_plus)=0.09123234379726985
# (D_linear_plus)=0.045614611272282744
# group
# D_linear_minus=0.11245077467338672
# (D_linear_minus + D_linear_plus)=0.26903743599522867
# group
# D_linear_minus=0.11250277038072061
# (D_linear_minus + D_linear_plus)=0.27025287528454034
# group
# D_linear_minus=0.04613147238973713
# (D_linear_minus + D_linear_plus)=0.09211006935285079
# (D_linear_plus)=0.04597859696311367
# group
# (D_linear_minus + D_linear_plus)=0.2709562850556066
# (D_linear_plus)=0.11320618015178684
# group
# D_linear_minus=0.11009748030906566
# (D_linear_minus + D_linear_plus)=0.264078663808442
# group
# D_linear_minus=0.044066500756291316
# (D_linear_minus + D_linear_plus)=0.08819586156456469
# (D_linear_plus)=0.044129360808273364
# group
# D_linear_minus=0.11320618015178684
# (D_linear_minus + D_linear_plus)=0.2240122053402125
# (D_linear_plus)=0.11080602518842564
# group
# D_linear_minus=0.10902973349862241
# (D_linear_minus + D_linear_plus)=0.2621578343426645
# group
# D_linear_minus=0.04405048626230523
# (D_linear_minus + D_linear_plus)=0.08818583613977446
# (D_linear_plus)=0.04413534987746923
# group
# D_linear_minus=0.11080602518842564
# (D_linear_minus + D_linear_plus)=0.2212335896753626
# (D_linear_plus)=0.11042756448693695
# group
# D_linear_minus=0.10909146446563726
# (D_linear_minus + D_linear_plus)=0.2623427674848412
# group
# D_linear_minus=0.04428810742523337
# (D_linear_minus + D_linear_plus)=0.08876932300789281
# (D_linear_plus)=0.04448121558265944
# group
# D_linear_minus=0.11042756448693695
# (D_linear_minus + D_linear_plus)=0.2226848221992912
# (D_linear_plus)=0.11225725771235424
# group
# D_linear_minus=0.11226708789278045
# (D_linear_minus + D_linear_plus)=0.26893617770803624
# group
# D_linear_minus=0.045614611272282744
# (D_linear_minus + D_linear_plus)=0.09093155799768017
# (D_linear_plus)=0.045316946725397426
# group
# D_linear_minus=0.11225725771235424
# (D_linear_minus + D_linear_plus)=0.26892634752761
# group
# D_linear_minus=0.11228864469851621
# (D_linear_minus + D_linear_plus)=0.26950750593086054
# group
# D_linear_minus=0.04597859696311367
# (D_linear_minus + D_linear_plus)=0.12348956476505765
# group
# (D_linear_minus + D_linear_plus)=0.26919442368559454
# (D_linear_plus)=0.1119755624532502
# group
# D_linear_minus=0.10958928129157543
# (D_linear_minus + D_linear_plus)=0.26179720949813984
# group
# D_linear_minus=0.044129360808273364
# (D_linear_minus + D_linear_plus)=0.11861781137401314
# group
# D_linear_minus=0.1119755624532502
# (D_linear_minus + D_linear_plus)=0.2218353703523901
# (D_linear_plus)=0.1098598078991399
# group
# D_linear_minus=0.10913396740168392
# (D_linear_minus + D_linear_plus)=0.2622135458205249
# group
# D_linear_minus=0.04413534987746923
# (D_linear_minus + D_linear_plus)=0.1191463671206268
# group
# D_linear_minus=0.1098598078991399
# (D_linear_minus + D_linear_plus)=0.22097240051148587
# (D_linear_plus)=0.11111259261234596
# group
# D_linear_minus=0.11050187742689749
# (D_linear_minus + D_linear_plus)=0.26512519183949124
# group
# D_linear_minus=0.04448121558265944
# (D_linear_minus + D_linear_plus)=0.120421018101203
# group
# D_linear_minus=0.11111259261234596
# (D_linear_minus + D_linear_plus)=0.22333130238895219
# (D_linear_plus)=0.11221870977660622
# group
# D_linear_minus=0.11121231431713972
# (D_linear_minus + D_linear_plus)=0.26639928357770487
# group
# D_linear_minus=0.045316946725397426
# (D_linear_minus + D_linear_plus)=0.12159692475676376
# group
# D_linear_minus=0.11221870977660622
# (D_linear_minus + D_linear_plus)=0.2674056790371714

# %%
linear_diffusive_terms[1][NEGATIVE_DIR][0, :, 0, 0]
# Out:
# array([0.07654931, 0.0454746 , 0.04548204, 0.04539332, 0.04544871,
#        0.04570013, 0.04579698, 0.04558903, 0.04587009, 0.04577041,
#        0.04524912, 0.04538698, 0.0458272 , 0.04607297, 0.04582106,
#        0.04582689, 0.04614648, 0.04627059, 0.04618804, 0.04597796])

# %%
# Generate neutron production matrix
neutron_production_matrix = np.zeros((number_of_groups, number_of_groups))

for x, y, z, energy in product(range(mesh_size_x), range(mesh_size_y), range(mesh_size_z), range(current_max_energy_group)):
    index_in_flattened_flux_vector = get_index_in_flattened_flux_vector(energy, x, y, z)
    for energy_group_h in range(current_max_energy_group):
        neutron_production_matrix[index_in_flattened_flux_vector, get_index_in_flattened_flux_vector(energy_group_h, x, y, z)] \
            += get_nu_bar(energy, x, y, z) * get_fission_xs(energy, energy_group_h, x, y, z)

    print(get_fission_xs(energy, energy, x, y, z))
#neutron_production_matrix += 0.01 * np.eye(number_of_grou
# Out:
# 0.164499
# 0.1691
# 0.172875
# 0.178144
# 0.159406
# 0.163443
# 0.176785
# 0.176166
# 0.173664
# 0.159648
# 0.169156
# 0.175098
# 0.178316
# 0.172365
# 0.164877
# 0.166223
# 0.177596
# 0.179439
# 0.174486
# 0.167139
# 0.166626
# 0.171675
# 0.171638
# 0.172421
# 0.159428
# 0.162386
# 0.173672
# 0.176302
# 0.17497
# 0.166027
# 0.159185
# 0.177595
# 0.177539
# 0.175702
# 0.16185
# 0.165144
# 0.174468
# 0.17684
# 0.170377
# 0.162445
# 0.159823
# 0.173291
# 0.177034
# 0.175413
# 0.163603
# 0.165308
# 0.174796
# 0.180779
# 0.179858
# 0.163248
# 0.165283
# 0.175848
# 0.177342
# 0.173016
# 0.160489
# 0.163274
# 0.174712
# 0.177588
# 0.175884
# 0.165888
# 0.165754
# 0.172606
# 0.177307
# 0.175082
# 0.167206
# 0.159765
# 0.175246
# 0.182348
# 0.173599
# 0.168969
# 0.163352
# 0.175769
# 0.178483
# 0.168454
# 0.164634
# 0.158515
# 0.175551
# 0.179205
# 0.173873
# 0.165594
# 0.164486
# 0.177345
# 0.180636
# 0.177566
# 0.162345
# 0.157656
# 0.172487
# 0.174342
# 0.17546
# 0.162146
# 0.163415
# 0.174411
# 0.177515
# 0.174152
# 0.158987
# 0.157479
# 0.174431
# 0.172924
# 0.174125
# 0.166193
# 0.17296
# 0.188448
# 0.18441
# 0.184082
# 0.180236
# 0.17328
# 0.186768
# 0.192083
# 0.186794
# 0.175924
# 0.174216
# 0.188537
# 0.186808
# 0.184247
# 0.173244
# 0.175035
# 0.186095
# 0.188942
# 0.186217
# 0.186799
# 0.172313
# 0.172656
# 0.189117
# 0.188434
# 0.186034
# 0.174412
# 0.176026
# 0.183626
# 0.189616
# 0.186858
# 0.175316
# 0.17658
# 0.187696
# 0.188991
# 0.185166
# 0.177857
# 0.175122
# 0.186185
# 0.191163
# 0.184914
# 0.16879
# 0.174668
# 0.190228
# 0.186617
# 0.186227
# 0.174733
# 0.174535
# 0.187992
# 0.190683
# 0.186899
# 0.172983
# 0.17482
# 0.189906
# 0.190601
# 0.183423
# 0.174238
# 0.177895
# 0.186231
# 0.186572
# 0.187829
# 0.174669
# 0.177685
# 0.181984
# 0.18591
# 0.183741
# 0.174207
# 0.180262
# 0.189526
# 0.186472
# 0.184324
# 0.17915
# 0.180583
# 0.186847
# 0.188578
# 0.189532
# 0.17429
# 0.174784
# 0.18266
# 0.18732
# 0.181957
# 0.174948
# 0.159111
# 0.177874
# 0.173005
# 0.16948
# 0.163406
# 0.159213
# 0.17744
# 0.177803
# 0.176113
# 0.163305
# 0.163268
# 0.173903
# 0.176543
# 0.170472
# 0.158229
# 0.160866
# 0.177387
# 0.177297
# 0.177283
# 0.163003
# 0.164388
# 0.174542
# 0.177473
# 0.178418
# 0.16058
# 0.164653
# 0.172355
# 0.180251
# 0.16957
# 0.1666
# 0.160409
# 0.176093
# 0.180298
# 0.173132
# 0.169385
# 0.166839
# 0.176478
# 0.173924
# 0.172522
# 0.158747
# 0.165676
# 0.177791
# 0.176117
# 0.17594
# 0.165766
# 0.166221
# 0.174231
# 0.174894
# 0.173617
# 0.163317
# 0.160511
# 0.176473
# 0.178141
# 0.173646
# 0.166429
# 0.167072
# 0.174022
# 0.17682
# 0.174543
# 0.161908
# 0.166555
# 0.174118
# 0.179473
# 0.174147
# 0.159257
# 0.162888
# 0.173002
# 0.177308
# 0.173093
# 0.168394
# 0.157673
# 0.172152
# 0.174832
# 0.176947
# 0.166145
# 0.161244
# 0.174992
# 0.175344
# 0.17451
# 0.157939
# 0.162415
# 0.174563
# 0.177227
# 0.174598
# 0.161748
# 0.159378
# 0.180702
# 0.178945
# 0.174096
# 0.163625
# 0.160591
# 0.174033
# 0.175146
# 0.177603
# 0.165213
# 0.163596
# 0.177238
# 0.176861
# 0.170106
# 0.16602

# %%
import matplotlib.pyplot as plt

plt.imshow((neutron_loss_matrix != 0))

print_matrix(neutron_loss_matrix)

# %%
import matplotlib.pyplot as plt

plt.imshow(neutron_production_matrix != 0)

print_matrix(neutron_production_matrix)

# %%
from scipy.linalg import eig

eigenvalues, eigenvectors = eig(neutron_loss_matrix, neutron_production_matrix, check_finite=True)

# %%
def convert_flattened_flux_into_matrix(flattened_flux):
    matrix = np.zeros((mesh_size_x, mesh_size_y, mesh_size_z, current_max_energy_group))
    for x, y, z, energy in product(range(mesh_size_x), range(mesh_size_y), range(mesh_size_z), range(current_max_energy_group)):
        index = get_index_in_flattened_flux_vector(energy, x, y, z)
        matrix[x, y, z, energy] = flattened_flux[index]
    return matrix

# %%
plt.plot(1 / np.array(eigenvalues))
plt.plot(sorted(1 / np.array(eigenvalues)))
print(eigenvectors)
# Out:
# [[ 0.00167366 -0.0036812  -0.00516609 ... -0.04535364 -0.06031947
#   -0.0004162 ]
#  [ 0.00351141 -0.00772686 -0.01085093 ... -0.12472541 -0.03204232
#   -0.01074836]
#  [ 0.00418542 -0.00921105 -0.01293731 ... -0.05092183  0.0267679
#    0.03621206]
#  ...
#  [ 0.00416596  0.00834039 -0.01308574 ... -0.00197219  0.07120305
#   -0.05740742]
#  [ 0.00348823  0.00698277 -0.0109539  ...  0.03335735 -0.03634757
#   -0.09475878]
#  [ 0.00166358  0.00332873 -0.00521847 ...  0.02603453 -0.05437221
#   -0.07885392]]
# /home/tom/.local/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
import matplotlib.pyplot as plt

fig, (ax1) = plt.subplots(1, 1, sharey=True)

predicted_flux = convert_flattened_flux_into_matrix(eigenvectors[np.argmin(eigenvalues)])
total_flux = predicted_flux[:, :, 0, 0].T
img1 = ax1.imshow(total_flux, extent=[-30, 30, -100, 100])

ax1.set_xlabel("x")
ax1.set_xlabel("y")
ax1.set_title("Max k")

fig.colorbar(img1)

# %%
# From stackoverflow
def gauss_seidel(A, b, tolerance, max_iterations, x):
    #x is the initial condition
    iter1 = 0
    #Iterate
    for k in range(max_iterations):
        iter1 = iter1 + 1
        x_old  = x.copy()
        
        #Loop over rows
        for i in range(A.shape[0]):
            x[i] = (b[i] - np.dot(A[i,:i], x[:i]) - np.dot(A[i,(i+1):], x_old[(i+1):])) / A[i ,i]
            
        #Stop condition 
        #LnormInf corresponds to the absolute value of the greatest element of the vector.
        
        LnormInf = max(abs((x - x_old)))/max(abs(x_old))   
        if  LnormInf < tolerance:
            break
    return x

# From openmc

def _check_convergence(s_n, s_o, k_n, k_o, iteration, innerits):
    """Checks the convergence of the CMFD problem

    Parameters
    ----------
    s_n : numpy.ndarray
        Source vector from current iteration
    s_o : numpy.ndarray
        Source vector from previous iteration
    k_n : float
        K-effective  from current iteration
    k_o : float
        K-effective from previous iteration
    iteration : int
        Iteration number
    innerits : int
        Number of iterations required for convergence in inner GS loop

    Returns
    -------
    iconv : bool
        Whether the power iteration has reached convergence
    serr : float
        Error in source from previous iteration to current iteration, used
        for dominance ratio calculations

    """
    # Calculate error in keff
    kerr = abs(k_o - k_n) / k_n

    # Calculate max error in source
    with np.errstate(divide='ignore', invalid='ignore'):
        serr = np.sqrt(np.sum(np.where(s_n > 0, ((s_n-s_o) / s_n)**2, 0))
                        / len(s_n))

    # Check for convergence
    iconv = kerr < 1.e-5 and serr < 1.e-4

    return iconv, serr

def _execute_power_iter(loss, prod):
    """Main power iteration routine for the CMFD calculation

    Parameters
    ----------
    loss : scipy.sparse.spmatrix
        Sparse matrix storing elements of CMFD loss matrix
    prod : scipy.sparse.spmatrix
        Sparse matrix storing elements of CMFD production matrix

    Returns
    -------
    phi_n : numpy.ndarray
        Flux vector of CMFD problem
    k_n : float
        Eigenvalue of CMFD problem
    dom : float
        Dominance ratio of CMFD problem

    """
    # Get problem size
    n = loss.shape[0]

    # Set up tolerances for C++ solver
    atoli = 1.e-10
    rtoli = 1.e-5
    toli = rtoli * 100

    # Set up flux vectors, intital guess set to 1
    phi_n = np.ones((n,))
    phi_o = np.ones((n,))

    # Set up source vectors
    s_n = np.zeros((n,))
    s_o = np.zeros((n,))

    # Set initial guess
    k_n = 1.5
    k_o = k_n
    dw = 1.e6
    k_s = k_o + dw
    k_ln = 1.0/(1.0/k_n - 1.0/k_s)
    k_lo = k_ln

    # Set norms to 0
    norm_n = 0.0
    norm_o = 0.0

    # Maximum number of power iterations
    maxits = 10000

    # Perform Wielandt shift
    loss -= 1.0/k_s*prod

    # Begin power iteration
    for i in range(maxits):
        if i % 20 == 0:
            print(f"Iteration {i}")
        # Check if reach max number of iterations
        if i == maxits - 1:
            raise RuntimeError('Reached maximum iterations in CMFD power '
                                'iteration solver.')

        # Compute source vector
        s_o = prod.dot(phi_o)

        # Normalize source vector
        s_o /= k_lo

        # Compute new flux with C++ solver
        innerits = gauss_seidel(loss, s_o, toli, 10000, phi_n)

        # Compute new source vector
        s_n = prod.dot(phi_n)

        # Compute new shifted eigenvalue
        k_ln = np.sum(s_n) / np.sum(s_o)

        # Compute new eigenvalue
        k_n = 1.0/(1.0/k_ln + 1.0/k_s)

        # Renormalize the old source
        s_o *= k_lo

        # Check convergence
        iconv, norm_n = _check_convergence(s_n, s_o, k_n, k_o, i+1, innerits)

        # If converged, calculate dominance ratio and break from loop
        if iconv:
            dom = norm_n / norm_o
            return phi_n, k_n, dom

        # Record old values if not converged
        phi_o = phi_n
        k_o = k_n
        k_lo = k_ln
        norm_o = norm_n

        # Update tolerance for inner iterations
        toli = max(atoli, rtoli*norm_n)

# %%
mc_flux, mc_k, dominance = _execute_power_iter(neutron_loss_matrix, neutron_production_matrix)
# Out:
# Iteration 0
# Iteration 20
# Iteration 40
# Iteration 60
# Iteration 80
# Iteration 100
# Iteration 120
# Iteration 140
# Iteration 160
# Iteration 180
# Iteration 200
# Iteration 220
# Iteration 240
# Iteration 260
# Iteration 280
# Iteration 300
# Iteration 320
# Iteration 340
# Iteration 360
# Iteration 380
# Iteration 400
# Iteration 420
# Iteration 440
# Iteration 460
# Iteration 480
# Iteration 500
# Iteration 520
# Iteration 540
# Iteration 560
# Iteration 580
# Iteration 600

# %%
import matplotlib.pyplot as plt

fig, (ax1) = plt.subplots(1, 1, sharey=True)

predicted_flux = convert_flattened_flux_into_matrix(mc_flux)
total_flux = np.sum(predicted_flux[:, :, :, 0], axis=2).T
img1 = ax1.imshow(total_flux, extent=[-30, 30, -100, 100])

ax1.set_xlabel("x")
ax1.set_xlabel("y")
ax1.set_title("Max k")

fig.colorbar(img1)

# %%
import matplotlib.pyplot as plt

fig, (ax1) = plt.subplots(1, 1, sharey=True)

total_flux = np.sum(flux_matrix[:, :, :, 0, 0, 0], axis=0)
img1 = ax1.imshow(total_flux, extent=[-30, 30, -100, 100])

ax1.set_xlabel("x")
ax1.set_xlabel("y")
ax1.set_title("Max k")

fig.colorbar(img1)
